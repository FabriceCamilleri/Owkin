# %% [markdown]
# # Preparation of the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import six
import SimpleITK as sitk
import radiomics
from radiomics import firstorder, glcm, imageoperations, shape, glrlm, glszm
from scipy import stats
from lifelines import CoxPHFitter
import metrics_t9gbvr2

# %% [markdown]
# ## Getting the data
#
# ### Clinical and provided radiomics data
#
# Function to prepate the data, according to the analysis of the data made.

# %%
def prepareDataSet(setType, keepAllEvent=True):
    # Fonction preparing the Training dataset or the Testing data set taking as argument "Training" or "Testing"
    # and keepALlevent boolean in case we want to get rid of the censored data to perform classical regression
    assert (setType == 'Training' or setType == 'Testing'), 'setType argument should be "Training" or "Testing"'
    assert (keepAllEvent == True or keepAllEvent == False), 'keepAllEvent argument should be "True or False'
    # We get the csv files
    clinics=pd.read_csv(setType+"/features/clinical_data.csv")
    radiomics=pd.read_csv(setType+"/features/radiomics.csv", header=1)
    # We rename the column 0
    radiomics.rename(columns = {'Unnamed: 0':'PatientID'}, inplace = True)
    # We get rid of the first row containing only NaN values
    radiomics=radiomics.drop([0])
    # We transform the column PatientID as numeric
    radiomics['PatientID']=pd.to_numeric(radiomics['PatientID'])
    # We create the dataSet
    dataSet=clinics
    dataSet=dataSet.merge(radiomics,on=['PatientID','PatientID'])
    # We set the index as being PatientID
    dataSet=dataSet.set_index('PatientID')
    # We rename some histology values
    dataSet['Histology'][dataSet['Histology']=='Adenocarcinoma']='adenocarcinoma'
    dataSet['Histology'][dataSet['Histology']=='Squamous cell carcinoma']='squamous cell carcinoma'
    #dataSet['Histology'][dataSet['Histology']=='NSCLC NOS (not otherwise specified)']='nos'

    # Standardization of the dataset
    
    #We create binary columns for Histology and Sourcedataset
    dataSet["Adenocarcinoma"] = np.where(dataSet['Histology']=='adenocarcinoma', 1, 0)
    dataSet["Squamous"] = np.where(dataSet['Histology']=='squamous cell carcinoma', 1, 0)
    dataSet["Nos"] = np.where(dataSet['Histology']=='nos', 1, 0)
    dataSet["Nscl"] = np.where(dataSet['Histology']=='NSCLC NOS (not otherwise specified)', 1, 0)
    dataSet["Largecell"] = np.where(dataSet['Histology']=='large cell', 1, 0)
    dataSet["SourceDataset"] = np.where(dataSet['SourceDataset']=='l2', 1, 0)
    # We delete the first column Histology
    dataSet.pop('Histology')
    # We standardize
    dataSet = (dataSet - dataSet.mean())/dataSet.std()
    # We set the missing ages to zero
    dataSet.age[dataSet.age.isnull()]=0  
    # If we want to create a Training set, we add as the last column the known Survival Time
    # They are not known for the Testing set. The only way to get a metric s to submit the output to challengedata.ens.f
    if (setType=='Training'):
        outputs=pd.read_csv("training/output_VSVxRFU.csv")
        dataSet=dataSet.merge(outputs,on=['PatientID','PatientID'])
        dataSet=dataSet.set_index('PatientID')
        if (keepAllEvent==False):
            dataSet=dataSet[dataSet['Event']==1]
            dataSet=dataSet.iloc[:,0:-1]
    return dataSet

# %% [markdown]
# ### Calculated radiomics data
#
# Function to calculate the radiomics data using pyradiomics, the scans and the masks.

# %%
# This function will create a datafram with PatientID as index, and with all calculated features with pyradiomics
# For the feature name we keep the naming convention used in the provided data
def calculateRadiomics(setType):
    assert (setType == 'Training' or setType == 'Testing'), 'setType argument should be "Training" or "Testing"'
    dataSet=pd.read_csv(setType+"/features/clinical_data.csv").set_index('PatientID')
    for i in dataSet.index:
        scandata= np.load(setType+'/images/patient_'+'0'*(3-len(str(i)))+str(i)+'.npz')
        # if the mask is not empty, else we don't do anything           
        if ((np.where(scandata['mask'], 1, 0)).max()==1):
            image= sitk.GetImageFromArray(scandata['scan'])
            mask = np.where(scandata['mask'], 1, 0)
            mask = sitk.GetImageFromArray(mask)

            # getting first order features
            firstOrderFeatures=firstorder.RadiomicsFirstOrder(image, mask)
            firstOrderFeatures.enableAllFeatures()
            result = firstOrderFeatures.execute()
            for (key, val) in six.iteritems(result):
                   dataSet.loc[i,'original_firstorder_'+key]=val

            # getting the shape features
            shapeFeatures = shape.RadiomicsShape(image, mask)
            shapeFeatures.enableAllFeatures()
            result = shapeFeatures.execute()
            for (key, val) in six.iteritems(result):
                dataSet.loc[i,'original_shape_'+key]=val

            # getting the Glcm features
            glcmFeatures = glcm.RadiomicsGLCM(image, mask)
            glcmFeatures.enableAllFeatures()
            result = glcmFeatures.execute()
            for (key, val) in six.iteritems(result):
                dataSet.loc[i,'original_glcm_'+key]=val

            # getting the Glrml features
            glrlmFeatures = glrlm.RadiomicsGLRLM(image, mask)
            glrlmFeatures.enableAllFeatures()
            result = glrlmFeatures.execute()
            for (key, val) in six.iteritems(result):
                dataSet.loc[i,'original_glrlm_'+key]=val

            # getting the Glszm features - not used 
            '''
            glszmFeatures = glszm.RadiomicsGLSZM(image, mask)
            glszmFeatures.enableAllFeatures()
            result = glszmFeatures.execute()
            for (key, val) in six.iteritems(result):
                dataSet.loc[i,'original_glszm_'+key]=val
            '''
    # We get rid of the first columns to keep only the calculated data
    dataSet=dataSet.iloc[:,6:]
    
    # We standardize
    dataSet = (dataSet - dataSet.mean())/dataSet.std()
    return dataSet

# %% [markdown]
# Function to get the metric

# %%
def getMetric (PredictedOutput, y_true_times):
    predicted_times=PredictedOutput
    predicted_times['Event']=np.nan
    #predicted_times2=predicted_times.append(y_true_times[y_true_times['Event']==0])
    return metrics_t9gbvr2.cindex(y_true_times, predicted_times, tol=1e-8)

# %% [markdown]
# ## Checking the data

# %% [markdown]
# ### Provided data

# %%
trainingSet=prepareDataSet('Training', standardized=False)
# Out:
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Function to go over the columns and get some information, in particular, for numerical values, to identify outliers, and NA
def checkData (set):
    for col in set:
        print ('####### Feature: '+ col + ' #######')
        print(set[col].describe())
        if (set[col].dtypes!='object'):
            print ('** Values for which the Z score is greather than 3 : **' )
            print(set[np.abs(stats.zscore(set[col]))>3][col])
            print ('** 5 smalles values: **')
            print(set[col].nsmallest(5))
            print ('** 5 highest values: **')
            print(set[col].nlargest(5)) 
            plt.figure(figsize=(3,3))
            plt.title(col)
            plt.boxplot(set[col][set[col].notnull()])
            plt.show
        else:
            print('** Values and Frequencies: **')
            print(set.groupby(col).size())

        print('** Number of NA: **')
        print(sum(set[col].isnull()))
        print('')

# %%
checkData(trainingSet)
# Out:
# ####### Feature: Histology #######
# count                280
# unique                 5
# top       adenocarcinoma
# freq                 101
# Name: Histology, dtype: object
# ** Values and Frequencies: **
# Histology
# NSCLC NOS (not otherwise specified)      2
# adenocarcinoma                         101
# large cell                              61
# nos                                     38
# squamous cell carcinoma                 78
# dtype: int64
# ** Number of NA: **
# 20
#
# ####### Feature: Mstage #######
# count    300.000000
# mean       0.040000
# std        0.314212
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        3.000000
# Name: Mstage, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 102    3
# 31     1
# 250    3
# 231    1
# 309    3
# 290    1
# Name: Mstage, dtype: int64
# ** 5 smalles values: **
# PatientID
# 202    0
# 371    0
# 246    0
# 240    0
# 284    0
# Name: Mstage, dtype: int64
# ** 5 highest values: **
# PatientID
# 102    3
# 250    3
# 309    3
# 31     1
# 231    1
# Name: Mstage, dtype: int64
# ** Number of NA: **
# 0
#
# ####### Feature: Nstage #######
# count    300.000000
# mean       0.963333
# std        1.160378
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.000000
# max        3.000000
# Name: Nstage, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: Nstage, dtype: int64)
# ** 5 smalles values: **
# PatientID
# 202    0
# 384    0
# 244    0
# 100    0
# 149    0
# Name: Nstage, dtype: int64
# ** 5 highest values: **
# PatientID
# 246    3
# 284    3
# 83     3
# 316    3
# 102    3
# Name: Nstage, dtype: int64
# ** Number of NA: **
# 0
#
# ####### Feature: SourceDataset #######
# count     300
# unique      2
# top        l1
# freq      199
# Name: SourceDataset, dtype: object
# ** Values and Frequencies: **
# SourceDataset
# l1    199
# l2    101
# dtype: int64
# ** Number of NA: **
# 0
#
# ####### Feature: Tstage #######
# count    300.000000
# mean       2.103333
# std        1.072297
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max        5.000000
# Name: Tstage, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: Tstage, dtype: int64)
# ** 5 smalles values: **
# PatientID
# 244    1
# 197    1
# 185    1
# 63     1
# 178    1
# Name: Tstage, dtype: int64
# ** 5 highest values: **
# PatientID
# 388    5
# 371    4
# 284    4
# 100    4
# 173    4
# Name: Tstage, dtype: int64
# ** Number of NA: **
# 0
#
# ####### Feature: age #######
# count    284.000000
# mean      68.766856
# std        9.587605
# min       42.513300
# 25%       62.979625
# 50%       69.947300
# 75%       76.201950
# max       87.126600
# Name: age, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: age, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 263    42.5133
# 23     43.0000
# 282    43.2827
# 213    43.3840
# 235    45.7276
# Name: age, dtype: float64
# ** 5 highest values: **
# PatientID
# 261    87.1266
# 52     87.0308
# 94     87.0000
# 123    86.0000
# 225    85.4949
# Name: age, dtype: float64
# ** Number of NA: **
# 16
#
# ####### Feature: original_shape_Compactness1 #######
# count    300.000000
# mean       0.026078
# std        0.006213
# min        0.009288
# 25%        0.022028
# 50%        0.026071
# 75%        0.030600
# max        0.042759
# Name: original_shape_Compactness1, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_Compactness1, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 277    0.009288
# 142    0.010078
# 102    0.010820
# 84     0.011653
# 298    0.011765
# Name: original_shape_Compactness1, dtype: float64
# ** 5 highest values: **
# PatientID
# 188    0.042759
# 11     0.039609
# 394    0.039019
# 22     0.038907
# 141    0.038652
# Name: original_shape_Compactness1, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_shape_Compactness2 #######
# count    300.000000
# mean       0.255309
# std        0.114462
# min        0.030648
# 25%        0.172413
# 50%        0.241503
# 75%        0.332701
# max        0.649631
# Name: original_shape_Compactness2, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 188    0.649631
# Name: original_shape_Compactness2, dtype: float64
# ** 5 smalles values: **
# PatientID
# 277    0.030648
# 142    0.036087
# 102    0.041598
# 84     0.048244
# 298    0.049182
# Name: original_shape_Compactness2, dtype: float64
# ** 5 highest values: **
# PatientID
# 188    0.649631
# 11     0.557429
# 394    0.540955
# 22     0.537858
# 141    0.530817
# Name: original_shape_Compactness2, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_shape_Maximum3DDiameter #######
# count    300.000000
# mean      63.735090
# std       35.533323
# min       13.453624
# 25%       33.915016
# 50%       57.823002
# 75%       82.933158
# max      216.716405
# Name: original_shape_Maximum3DDiameter, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 142    174.014367
# 328    216.716405
# 3      178.117938
# Name: original_shape_Maximum3DDiameter, dtype: float64
# ** 5 smalles values: **
# PatientID
# 188    13.453624
# 115    13.674794
# 63     16.583124
# 394    16.763055
# 11     17.117243
# Name: original_shape_Maximum3DDiameter, dtype: float64
# ** 5 highest values: **
# PatientID
# 328    216.716405
# 3      178.117938
# 142    174.014367
# 367    163.376865
# 355    158.041134
# Name: original_shape_Maximum3DDiameter, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_shape_SphericalDisproportion #######
# count    300.000000
# mean       1.666887
# std        0.321580
# min        1.154634
# 25%        1.443163
# 50%        1.605803
# 75%        1.796703
# max        3.195442
# Name: original_shape_SphericalDisproportion, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 316    2.709793
# 102    2.886086
# 145    2.632693
# 43     2.641758
# 142    3.026090
# 277    3.195442
# 84     2.746952
# 298    2.729392
# Name: original_shape_SphericalDisproportion, dtype: float64
# ** 5 smalles values: **
# PatientID
# 188    1.154634
# 11     1.215076
# 394    1.227287
# 22     1.229639
# 141    1.235051
# Name: original_shape_SphericalDisproportion, dtype: float64
# ** 5 highest values: **
# PatientID
# 277    3.195442
# 142    3.026090
# 102    2.886086
# 84     2.746952
# 298    2.729392
# Name: original_shape_SphericalDisproportion, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_shape_Sphericity #######
# count    300.000000
# mean       0.618682
# std        0.101082
# min        0.312946
# 25%        0.556575
# 50%        0.622741
# 75%        0.692923
# max        0.866075
# Name: original_shape_Sphericity, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 277    0.312946
# Name: original_shape_Sphericity, dtype: float64
# ** 5 smalles values: **
# PatientID
# 277    0.312946
# 142    0.330459
# 102    0.346490
# 84     0.364040
# 298    0.366382
# Name: original_shape_Sphericity, dtype: float64
# ** 5 highest values: **
# PatientID
# 188    0.866075
# 11     0.822994
# 394    0.814805
# 22     0.813247
# 141    0.809683
# Name: original_shape_Sphericity, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_shape_SurfaceArea #######
# count      300.000000
# mean     10269.274116
# std      11020.943961
# min        409.699505
# 25%       2187.199167
# 50%       5669.467145
# 75%      14084.942660
# max      67799.783468
# Name: original_shape_SurfaceArea, dtype: float64
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\lib\function_base.py:3826: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1316: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1323: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1331: RuntimeWarning: invalid value encountered in less
#   x[x < stats['whislo']],
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1332: RuntimeWarning: invalid value encountered in greater
#   x[x > stats['whishi']],
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 23     45531.768327
# 124    47668.783309
# 269    47979.476819
# 84     67799.783468
# Name: original_shape_SurfaceArea, dtype: float64
# ** 5 smalles values: **
# PatientID
# 188    409.699505
# 394    478.783559
# 115    495.478741
# 331    545.631663
# 24     566.280840
# Name: original_shape_SurfaceArea, dtype: float64
# ** 5 highest values: **
# PatientID
# 84     67799.783468
# 269    47979.476819
# 124    47668.783309
# 23     45531.768327
# 316    43023.020493
# Name: original_shape_SurfaceArea, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_shape_SurfaceVolumeRatio #######
# count    300.000000
# mean       0.332531
# std        0.165777
# min        0.092706
# 25%        0.200968
# 50%        0.296289
# 75%        0.426285
# max        0.828710
# Name: original_shape_SurfaceVolumeRatio, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_SurfaceVolumeRatio, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 107    0.092706
# 269    0.095487
# 159    0.098852
# 30     0.108330
# 48     0.113191
# Name: original_shape_SurfaceVolumeRatio, dtype: float64
# ** 5 highest values: **
# PatientID
# 121    0.828710
# 149    0.817500
# 362    0.771608
# 290    0.766000
# 381    0.763391
# Name: original_shape_SurfaceVolumeRatio, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_shape_VoxelVolume #######
# count       300.000000
# mean      55941.000000
# std       82370.656898
# min         640.000000
# 25%        5586.750000
# 50%       19523.000000
# 75%       68332.250000
# max      502660.000000
# Name: original_shape_VoxelVolume, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 48     374525.0
# 224    319964.0
# 355    331761.0
# 90     310977.0
# 107    422584.0
# 124    345782.0
# 269    502660.0
# 414    319132.0
# 159    359838.0
# 84     364882.0
# Name: original_shape_VoxelVolume, dtype: float64
# ** 5 smalles values: **
# PatientID
# 188    640.0
# 394    738.0
# 115    756.0
# 24     766.0
# 381    798.0
# Name: original_shape_VoxelVolume, dtype: float64
# ** 5 highest values: **
# PatientID
# 269    502660.0
# 107    422584.0
# 48     374525.0
# 84     364882.0
# 159    359838.0
# Name: original_shape_VoxelVolume, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_Energy #######
# count    3.000000e+02
# mean     2.725407e+09
# std      5.094067e+09
# min      2.388461e+07
# 25%      5.434917e+08
# 50%      1.093244e+09
# 75%      2.994063e+09
# max      5.101016e+10
# Name: original_firstorder_Energy, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 21     1.952039e+10
# 414    4.668396e+10
# 159    1.982027e+10
# 84     5.101016e+10
# Name: original_firstorder_Energy, dtype: float64
# ** 5 smalles values: **
# PatientID
# 263    23884613.0
# 93     30817172.0
# 418    39323832.0
# 380    43640047.0
# 11     49747874.0
# Name: original_firstorder_Energy, dtype: float64
# ** 5 highest values: **
# PatientID
# 84     5.101016e+10
# 414    4.668396e+10
# 159    1.982027e+10
# 21     1.952039e+10
# 354    1.720423e+10
# Name: original_firstorder_Energy, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_Entropy #######
# count    300.000000
# mean       4.232072
# std        0.895564
# min        2.178197
# 25%        3.539630
# 50%        4.372496
# 75%        5.017558
# max        5.585623
# Name: original_firstorder_Entropy, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Entropy, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 5      2.178197
# 204    2.232123
# 388    2.288307
# 303    2.308623
# 216    2.364071
# Name: original_firstorder_Entropy, dtype: float64
# ** 5 highest values: **
# PatientID
# 244    5.585623
# 72     5.551119
# 82     5.542684
# 197    5.531607
# 151    5.523894
# Name: original_firstorder_Entropy, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_Kurtosis #######
# count    300.000000
# mean       8.890333
# std       13.519950
# min        1.385668
# 25%        2.150392
# 50%        3.663465
# 75%        9.412576
# max       98.477426
# Name: original_firstorder_Kurtosis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 173    89.097195
# 367    78.825240
# 90     98.477426
# 107    96.273848
# 373    52.067419
# 5      49.581787
# 298    57.125568
# 129    51.791276
# Name: original_firstorder_Kurtosis, dtype: float64
# ** 5 smalles values: **
# PatientID
# 195    1.385668
# 331    1.505974
# 22     1.564078
# 277    1.567239
# 375    1.570378
# Name: original_firstorder_Kurtosis, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     98.477426
# 107    96.273848
# 173    89.097195
# 367    78.825240
# 298    57.125568
# Name: original_firstorder_Kurtosis, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_Maximum #######
# count     300.000000
# mean      400.466667
# std       398.870750
# min       -71.000000
# 25%       143.000000
# 50%       267.500000
# 75%       509.250000
# max      3068.000000
# Name: original_firstorder_Maximum, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 134    2700.0
# 90     3068.0
# 98     2116.0
# Name: original_firstorder_Maximum, dtype: float64
# ** 5 smalles values: **
# PatientID
# 409   -71.0
# 304    20.0
# 105    21.0
# 305    32.0
# 148    36.0
# Name: original_firstorder_Maximum, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     3068.0
# 134    2700.0
# 98     2116.0
# 84     1587.0
# 112    1570.0
# Name: original_firstorder_Maximum, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_Mean #######
# count    300.000000
# mean    -162.813816
# std      161.026270
# min     -665.552148
# 25%     -274.440231
# 50%     -123.667304
# 75%      -34.366815
# max       70.708175
# Name: original_firstorder_Mean, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 193   -665.552148
# 39    -657.507022
# 409   -657.747911
# Name: original_firstorder_Mean, dtype: float64
# ** 5 smalles values: **
# PatientID
# 193   -665.552148
# 409   -657.747911
# 39    -657.507022
# 25    -621.045759
# 70    -611.415526
# Name: original_firstorder_Mean, dtype: float64
# ** 5 highest values: **
# PatientID
# 4      70.708175
# 107    69.646636
# 90     68.509954
# 100    55.935052
# 367    55.533568
# Name: original_firstorder_Mean, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_MeanAbsoluteDeviation #######
# count    300.000000
# mean     167.128062
# std       83.895591
# min       26.784907
# 25%      100.209692
# 50%      163.258113
# 75%      226.872132
# max      371.972581
# Name: original_firstorder_MeanAbsoluteDeviation, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_MeanAbsoluteDeviation, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367    26.784907
# 129    27.675471
# 107    28.039448
# 204    28.427726
# 263    30.207036
# Name: original_firstorder_MeanAbsoluteDeviation, dtype: float64
# ** 5 highest values: **
# PatientID
# 72     371.972581
# 282    356.512170
# 53     344.836621
# 183    341.094939
# 333    340.498362
# Name: original_firstorder_MeanAbsoluteDeviation, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_Median #######
# count    300.000000
# mean    -113.733333
# std      192.090246
# min     -776.000000
# 25%     -205.500000
# 50%      -15.500000
# 75%       20.000000
# max       75.000000
# Name: original_firstorder_Median, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 193   -695.0
# 39    -776.0
# 409   -705.0
# Name: original_firstorder_Median, dtype: float64
# ** 5 smalles values: **
# PatientID
# 39    -776.0
# 409   -705.0
# 193   -695.0
# 70    -685.0
# 282   -683.0
# Name: original_firstorder_Median, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     75.0
# 316    72.0
# 107    72.0
# 358    69.0
# 26     68.0
# Name: original_firstorder_Median, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_Minimum #######
# count     300.000000
# mean     -921.730000
# std       102.347678
# min     -1159.000000
# 25%     -1011.000000
# 50%      -952.000000
# 75%      -855.750000
# max      -491.000000
# Name: original_firstorder_Minimum, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 100   -613.0
# 418   -491.0
# 93    -553.0
# 263   -589.0
# Name: original_firstorder_Minimum, dtype: float64
# ** 5 smalles values: **
# PatientID
# 88    -1159.0
# 244   -1024.0
# 423   -1024.0
# 197   -1024.0
# 53    -1024.0
# Name: original_firstorder_Minimum, dtype: float64
# ** 5 highest values: **
# PatientID
# 418   -491.0
# 93    -553.0
# 263   -589.0
# 100   -613.0
# 110   -646.0
# Name: original_firstorder_Minimum, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_Range #######
# count     300.000000
# mean     1322.196667
# std       432.268618
# min       656.000000
# 25%      1027.250000
# 50%      1228.000000
# 75%      1498.000000
# max      4055.000000
# Name: original_firstorder_Range, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 134    3716.0
# 90     4055.0
# 98     3140.0
# Name: original_firstorder_Range, dtype: float64
# ** 5 smalles values: **
# PatientID
# 93     656.0
# 263    697.0
# 303    787.0
# 73     797.0
# 24     812.0
# Name: original_firstorder_Range, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     4055.0
# 134    3716.0
# 98     3140.0
# 84     2611.0
# 112    2550.0
# Name: original_firstorder_Range, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_RootMeanSquared #######
# count    300.000000
# mean     282.148891
# std      153.524367
# min       53.646685
# 25%      153.444652
# 50%      253.387189
# 75%      398.809163
# max      723.096011
# Name: original_firstorder_RootMeanSquared, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_RootMeanSquared, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 129    53.646685
# 263    55.205733
# 110    58.627263
# 269    63.044222
# 204    63.404911
# Name: original_firstorder_RootMeanSquared, dtype: float64
# ** 5 highest values: **
# PatientID
# 39     723.096011
# 193    692.519467
# 409    682.915240
# 70     668.985706
# 25     668.934361
# Name: original_firstorder_RootMeanSquared, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_Skewness #######
# count    300.000000
# mean      -1.455251
# std        1.551742
# min       -8.176859
# 25%       -2.293120
# 50%       -1.112103
# 75%       -0.453646
# max        1.996607
# Name: original_firstorder_Skewness, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 173   -8.176859
# 367   -6.363708
# 107   -7.662433
# 5     -6.118429
# Name: original_firstorder_Skewness, dtype: float64
# ** 5 smalles values: **
# PatientID
# 173   -8.176859
# 107   -7.662433
# 367   -6.363708
# 5     -6.118429
# 373   -5.896006
# Name: original_firstorder_Skewness, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     1.996607
# 397    1.238971
# 193    1.151143
# 100    1.141738
# 39     1.060952
# Name: original_firstorder_Skewness, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_StandardDeviation #######
# count    300.000000
# mean     209.789808
# std       82.210462
# min       49.522001
# 25%      146.545979
# 50%      212.783904
# 75%      268.370005
# max      416.260320
# Name: original_firstorder_StandardDeviation, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_StandardDeviation, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 129    49.522001
# 367    49.571710
# 110    51.590670
# 263    54.148528
# 204    61.218809
# Name: original_firstorder_StandardDeviation, dtype: float64
# ** 5 highest values: **
# PatientID
# 72     416.260320
# 282    412.533398
# 53     385.514159
# 183    374.200774
# 333    372.728318
# Name: original_firstorder_StandardDeviation, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_Uniformity #######
# count    300.000000
# mean       0.104487
# std        0.078533
# min        0.023359
# 25%        0.037459
# 50%        0.078592
# 75%        0.153789
# max        0.400577
# Name: original_firstorder_Uniformity, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 303    0.400577
# Name: original_firstorder_Uniformity, dtype: float64
# ** 5 smalles values: **
# PatientID
# 244    0.023359
# 197    0.023529
# 82     0.024031
# 151    0.024503
# 323    0.024506
# Name: original_firstorder_Uniformity, dtype: float64
# ** 5 highest values: **
# PatientID
# 303    0.400577
# 5      0.337551
# 204    0.333214
# 216    0.323348
# 388    0.321780
# Name: original_firstorder_Uniformity, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_firstorder_Variance #######
# count       300.000000
# mean      50747.795018
# std       36012.130280
# min        2452.428625
# 25%       21475.791564
# 50%       45277.022049
# 75%       72022.462049
# max      173272.654304
# Name: original_firstorder_Variance, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 282    170183.804262
# 72     173272.654304
# Name: original_firstorder_Variance, dtype: float64
# ** 5 smalles values: **
# PatientID
# 129    2452.428625
# 367    2457.354446
# 110    2661.597204
# 263    2932.063133
# 204    3747.742581
# Name: original_firstorder_Variance, dtype: float64
# ** 5 highest values: **
# PatientID
# 72     173272.654304
# 282    170183.804262
# 53     148621.166724
# 183    140026.219577
# 333    138926.398888
# Name: original_firstorder_Variance, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_Autocorrelation #######
# count     300.000000
# mean     1132.074310
# std       376.497864
# min       271.723565
# 25%       866.056233
# 50%      1144.727078
# 75%      1415.864410
# max      1972.666506
# Name: original_glcm_Autocorrelation, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_Autocorrelation, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 409    271.723565
# 193    285.900887
# 211    345.572463
# 25     354.454923
# 188    357.122561
# Name: original_glcm_Autocorrelation, dtype: float64
# ** 5 highest values: **
# PatientID
# 107    1972.666506
# 90     1897.788141
# 316    1887.908267
# 96     1853.915144
# 33     1852.026284
# Name: original_glcm_Autocorrelation, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_ClusterProminence #######
# count    3.000000e+02
# mean     3.196540e+05
# std      3.318146e+05
# min      2.271162e+03
# 25%      9.469413e+04
# 50%      2.270619e+05
# 75%      4.305865e+05
# max      2.979373e+06
# Name: original_glcm_ClusterProminence, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 116    1.708299e+06
# 282    2.979373e+06
# 414    1.936317e+06
# 72     1.678354e+06
# Name: original_glcm_ClusterProminence, dtype: float64
# ** 5 smalles values: **
# PatientID
# 110     2271.162485
# 263     4871.171312
# 129     6889.281619
# 93      9418.691775
# 367    10211.903533
# Name: original_glcm_ClusterProminence, dtype: float64
# ** 5 highest values: **
# PatientID
# 282    2.979373e+06
# 414    1.936317e+06
# 116    1.708299e+06
# 72     1.678354e+06
# 294    1.234937e+06
# Name: original_glcm_ClusterProminence, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_ClusterShade #######
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# count      300.000000
# mean     -3534.372971
# std       5057.830899
# min     -28739.715459
# 25%      -5644.848397
# 50%      -2830.357691
# 75%      -1017.068944
# max      34365.314521
# Name: original_glcm_ClusterShade, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 116   -22797.084256
# 39     11797.199067
# 78     13719.795137
# 294   -19072.081064
# 282    34365.314521
# 414   -28739.715459
# Name: original_glcm_ClusterShade, dtype: float64
# ** 5 smalles values: **
# PatientID
# 414   -28739.715459
# 116   -22797.084256
# 294   -19072.081064
# 30    -15682.159434
# 354   -14505.031632
# Name: original_glcm_ClusterShade, dtype: float64
# ** 5 highest values: **
# PatientID
# 282    34365.314521
# 78     13719.795137
# 39     11797.199067
# 72      8769.446506
# 70      5049.698426
# Name: original_glcm_ClusterShade, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_ClusterTendency #######
# count     300.000000
# mean      264.998361
# std       197.650840
# min        10.944156
# 25%       108.286665
# 50%       233.533941
# 75%       385.126631
# max      1025.758898
# Name: original_glcm_ClusterTendency, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 116     862.629742
# 282     970.713471
# 72     1025.758898
# Name: original_glcm_ClusterTendency, dtype: float64
# ** 5 smalles values: **
# PatientID
# 129    10.944156
# 263    11.294159
# 367    11.675222
# 110    12.089037
# 269    17.279227
# Name: original_glcm_ClusterTendency, dtype: float64
# ** 5 highest values: **
# PatientID
# 72     1025.758898
# 282     970.713471
# 116     862.629742
# 53      829.407969
# 331     792.660503
# Name: original_glcm_ClusterTendency, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_Contrast #######
# count    300.000000
# mean      30.594646
# std       31.973293
# min        1.180982
# 25%        8.493175
# 50%       17.595697
# 75%       38.838107
# max      156.034544
# Name: original_glcm_Contrast, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 244    156.034544
# 390    147.592805
# 368    138.700002
# Name: original_glcm_Contrast, dtype: float64
# ** 5 smalles values: **
# PatientID
# 367    1.180982
# 129    1.439822
# 204    1.637255
# 107    1.699316
# 16     1.964064
# Name: original_glcm_Contrast, dtype: float64
# ** 5 highest values: **
# PatientID
# 244    156.034544
# 390    147.592805
# 368    138.700002
# 151    125.936528
# 279    122.909066
# Name: original_glcm_Contrast, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_Correlation #######
# count    300.000000
# mean       0.800481
# std        0.100714
# min        0.382125
# 25%        0.749270
# 50%        0.823917
# 75%        0.874052
# max        0.960742
# Name: original_glcm_Correlation, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 280    0.382125
# 381    0.485697
# Name: original_glcm_Correlation, dtype: float64
# ** 5 smalles values: **
# PatientID
# 280    0.382125
# 381    0.485697
# 390    0.499882
# 258    0.501968
# 77     0.513115
# Name: original_glcm_Correlation, dtype: float64
# ** 5 highest values: **
# PatientID
# 78     0.960742
# 294    0.959325
# 282    0.957987
# 414    0.955543
# 159    0.951655
# Name: original_glcm_Correlation, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_DifferenceEntropy #######
# count    300.000000
# mean       3.001776
# std        0.808598
# min        1.250895
# 25%        2.378421
# 50%        3.019433
# 75%        3.658343
# max        4.629836
# Name: original_glcm_DifferenceEntropy, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_DifferenceEntropy, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367    1.250895
# 107    1.399395
# 204    1.407489
# 129    1.440679
# 5      1.497253
# Name: original_glcm_DifferenceEntropy, dtype: float64
# ** 5 highest values: **
# PatientID
# 244    4.629836
# 390    4.560040
# 151    4.462020
# 368    4.459184
# 121    4.423732
# Name: original_glcm_DifferenceEntropy, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_DifferenceAverage #######
# count    300.000000
# mean       3.208817
# std        1.999398
# min        0.506852
# 25%        1.627369
# 50%        2.675989
# 75%        4.457312
# max        9.048318
# Name: original_glcm_DifferenceAverage, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_DifferenceAverage, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367    0.506852
# 204    0.587801
# 107    0.600673
# 129    0.633557
# 5      0.701258
# Name: original_glcm_DifferenceAverage, dtype: float64
# ** 5 highest values: **
# PatientID
# 244    9.048318
# 390    8.709344
# 368    8.164736
# 121    8.039922
# 151    7.998409
# Name: original_glcm_DifferenceAverage, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_JointEnergy #######
# count    300.000000
# mean       0.037707
# std        0.042956
# min        0.001209
# 25%        0.004732
# 50%        0.022264
# 75%        0.058928
# max        0.311225
# Name: original_glcm_JointEnergy, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 37     0.179339
# 303    0.311225
# 388    0.177337
# 204    0.189076
# 216    0.168567
# 5      0.174834
# Name: original_glcm_JointEnergy, dtype: float64
# ** 5 smalles values: **
# PatientID
# 321    0.001209
# 288    0.001249
# 178    0.001277
# 197    0.001346
# 143    0.001431
# Name: original_glcm_JointEnergy, dtype: float64
# ** 5 highest values: **
# PatientID
# 303    0.311225
# 204    0.189076
# 37     0.179339
# 388    0.177337
# 5      0.174834
# Name: original_glcm_JointEnergy, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_JointEntropy #######
# count    300.000000
# mean       7.334689
# std        1.767280
# min        3.616187
# 25%        5.958355
# 50%        7.447514
# 75%        8.774603
# max       10.362353
# Name: original_glcm_JointEntropy, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_JointEntropy, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 204    3.616187
# 5      3.632354
# 303    3.635948
# 388    3.742104
# 367    3.855816
# Name: original_glcm_JointEntropy, dtype: float64
# ** 5 highest values: **
# PatientID
# 197    10.362353
# 244    10.330299
# 53     10.317640
# 151    10.299920
# 72     10.285854
# Name: original_glcm_JointEntropy, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_Id #######
# count    300.000000
# mean       0.479932
# std        0.151545
# min        0.229641
# 25%        0.338209
# 50%        0.478544
# 75%        0.612418
# max        0.787328
# Name: original_glcm_Id, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_Id, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 244    0.229641
# 143    0.230048
# 121    0.235656
# 321    0.240047
# 362    0.240815
# Name: original_glcm_Id, dtype: float64
# ** 5 highest values: **
# PatientID
# 367    0.787328
# 204    0.782234
# 37     0.778493
# 107    0.766711
# 303    0.764970
# Name: original_glcm_Id, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_Idm #######
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# count    300.000000
# mean       0.423750
# std        0.175137
# min        0.142743
# 25%        0.261793
# 50%        0.421700
# 75%        0.576300
# max        0.781492
# Name: original_glcm_Idm, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_Idm, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 143    0.142743
# 244    0.151361
# 321    0.151846
# 362    0.152447
# 121    0.152894
# Name: original_glcm_Idm, dtype: float64
# ** 5 highest values: **
# PatientID
# 367    0.781492
# 204    0.772832
# 37     0.765707
# 107    0.757463
# 388    0.751461
# Name: original_glcm_Idm, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_Imc1 #######
# count    300.000000
# mean      -0.224732
# std        0.064756
# min       -0.445933
# 25%       -0.266783
# 50%       -0.230240
# 75%       -0.176930
# max       -0.042944
# Name: original_glcm_Imc1, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 282   -0.445933
# Name: original_glcm_Imc1, dtype: float64
# ** 5 smalles values: **
# PatientID
# 282   -0.445933
# 331   -0.387496
# 90    -0.367233
# 78    -0.359610
# 414   -0.357801
# Name: original_glcm_Imc1, dtype: float64
# ** 5 highest values: **
# PatientID
# 423   -0.042944
# 185   -0.083858
# 130   -0.098483
# 391   -0.099163
# 77    -0.100516
# Name: original_glcm_Imc1, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_Imc2 #######
# count    300.000000
# mean       0.889318
# std        0.062526
# min        0.517424
# 25%        0.865116
# 50%        0.902664
# 75%        0.930980
# max        0.992772
# Name: original_glcm_Imc2, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 173    0.618398
# 423    0.517424
# 258    0.648420
# 77     0.658972
# Name: original_glcm_Imc2, dtype: float64
# ** 5 smalles values: **
# PatientID
# 423    0.517424
# 173    0.618398
# 258    0.648420
# 77     0.658972
# 391    0.710408
# Name: original_glcm_Imc2, dtype: float64
# ** 5 highest values: **
# PatientID
# 282    0.992772
# 331    0.989191
# 78     0.986079
# 188    0.976249
# 121    0.975267
# Name: original_glcm_Imc2, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_Idmn #######
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# count    300.000000
# mean       0.988846
# std        0.010519
# min        0.946453
# 25%        0.982654
# 50%        0.992632
# 75%        0.997378
# max        0.999777
# Name: original_glcm_Idmn, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 394    0.946453
# 390    0.956021
# 290    0.955771
# Name: original_glcm_Idmn, dtype: float64
# ** 5 smalles values: **
# PatientID
# 394    0.946453
# 290    0.955771
# 390    0.956021
# 368    0.957406
# 115    0.957948
# Name: original_glcm_Idmn, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     0.999777
# 367    0.999718
# 107    0.999669
# 248    0.999633
# 204    0.999580
# Name: original_glcm_Idmn, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_Idn #######
# count    300.000000
# mean       0.945115
# std        0.032398
# min        0.853036
# 25%        0.918477
# 50%        0.951108
# 75%        0.974457
# max        0.994299
# Name: original_glcm_Idn, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_Idn, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 394    0.853036
# 290    0.866700
# 390    0.873098
# 273    0.873813
# 115    0.875822
# Name: original_glcm_Idn, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     0.994299
# 367    0.992342
# 107    0.991845
# 204    0.990910
# 248    0.990341
# Name: original_glcm_Idn, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_InverseVariance #######
# count    300.000000
# mean       0.313875
# std        0.082071
# min        0.150059
# 25%        0.245698
# 50%        0.320341
# 75%        0.380464
# max        0.474754
# Name: original_glcm_InverseVariance, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_InverseVariance, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 143    0.150059
# 244    0.153774
# 321    0.156986
# 362    0.158662
# 121    0.158788
# Name: original_glcm_InverseVariance, dtype: float64
# ** 5 highest values: **
# PatientID
# 173    0.474754
# 313    0.474165
# 16     0.470602
# 269    0.469927
# 247    0.463553
# Name: original_glcm_InverseVariance, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_MaximumProbability #######
# count    300.000000
# mean       0.102365
# std        0.088305
# min        0.003717
# 25%        0.025643
# 50%        0.082705
# 75%        0.163411
# max        0.548944
# Name: original_glcm_MaximumProbability, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 303    0.548944
# Name: original_glcm_MaximumProbability, dtype: float64
# ** 5 smalles values: **
# PatientID
# 288    0.003717
# 32     0.003806
# 321    0.004152
# 143    0.004411
# 3      0.004582
# Name: original_glcm_MaximumProbability, dtype: float64
# ** 5 highest values: **
# PatientID
# 303    0.548944
# 204    0.365959
# 5      0.352147
# 37     0.336745
# 216    0.329852
# Name: original_glcm_MaximumProbability, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_SumAverage #######
# count    300.000000
# mean      64.303560
# std       12.616793
# min       29.568848
# 25%       56.599069
# 50%       64.823104
# 75%       73.393215
# max       88.714748
# Name: original_glcm_SumAverage, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_SumAverage, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 282    29.568848
# 409    30.390681
# 193    31.319598
# 39     33.187024
# 211    33.816524
# Name: original_glcm_SumAverage, dtype: float64
# ** 5 highest values: **
# PatientID
# 107    88.714748
# 90     86.763085
# 316    86.521923
# 33     85.471813
# 173    84.916946
# Name: original_glcm_SumAverage, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glcm_SumEntropy #######
# count    300.000000
# mean       5.019410
# std        0.942364
# min        2.787347
# 25%        4.289283
# 50%        5.132680
# 75%        5.891534
# max        6.537497
# Name: original_glcm_SumEntropy, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_SumEntropy, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 303    2.787347
# 204    2.906727
# 5      2.913820
# 388    2.957743
# 216    3.059383
# Name: original_glcm_SumEntropy, dtype: float64
# ** 5 highest values: **
# PatientID
# 72     6.537497
# 197    6.472942
# 53     6.423969
# 244    6.418605
# 82     6.381614
# Name: original_glcm_SumEntropy, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glrlm_ShortRunEmphasis #######
# count    300.000000
# mean       0.846900
# std        0.093955
# min        0.568045
# 25%        0.775595
# 50%        0.865672
# 75%        0.931728
# max        0.969945
# Name: original_glrlm_ShortRunEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_ShortRunEmphasis, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367    0.568045
# 107    0.583575
# 204    0.587459
# 216    0.626689
# 37     0.629369
# Name: original_glrlm_ShortRunEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 143    0.969945
# 362    0.969080
# 121    0.968379
# 321    0.965666
# 244    0.965224
# Name: original_glrlm_ShortRunEmphasis, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glrlm_LongRunEmphasis #######
# count    300.000000
# mean       2.997984
# std        2.277218
# min        1.129743
# 25%        1.380404
# 50%        2.183706
# 75%        3.928845
# max       19.569205
# Name: original_glrlm_LongRunEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 37     14.162044
# 303    19.569205
# 367    10.893396
# 388    10.806165
# 107     9.945471
# 204    13.018280
# Name: original_glrlm_LongRunEmphasis, dtype: float64
# ** 5 smalles values: **
# PatientID
# 143    1.129743
# 362    1.136824
# 121    1.138374
# 321    1.155567
# 163    1.159898
# Name: original_glrlm_LongRunEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 303    19.569205
# 37     14.162044
# 204    13.018280
# 367    10.893396
# 388    10.806165
# Name: original_glrlm_LongRunEmphasis, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glrlm_GrayLevelNonUniformity #######
# count      300.000000
# mean      4028.912972
# std       7354.203503
# min         20.662759
# 25%        179.737494
# 50%        891.648859
# 75%       4138.067422
# max      61727.567864
# Name: original_glrlm_GrayLevelNonUniformity, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 48     35017.987960
# 224    28076.948267
# 355    29388.284082
# 107    38384.558752
# 124    36275.900830
# 204    28101.746015
# 269    61727.567864
# Name: original_glrlm_GrayLevelNonUniformity, dtype: float64
# ** 5 smalles values: **
# PatientID
# 121    20.662759
# 331    22.015612
# 188    22.045298
# 394    22.483003
# 115    23.185525
# Name: original_glrlm_GrayLevelNonUniformity, dtype: float64
# ** 5 highest values: **
# PatientID
# 269    61727.567864
# 107    38384.558752
# 124    36275.900830
# 48     35017.987960
# 355    29388.284082
# Name: original_glrlm_GrayLevelNonUniformity, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glrlm_RunLengthNonUniformity #######
# count       300.000000
# mean      21708.293730
# std       30741.811717
# min         503.361305
# 25%        3594.097996
# 50%       10812.628268
# 75%       28318.086695
# max      267812.272378
# Name: original_glrlm_RunLengthNonUniformity, dtype: float64
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 48     205566.497796
# 30     125783.285418
# 23     158405.539844
# 269    149359.216155
# 21     117004.862909
# 84     267812.272378
# Name: original_glrlm_RunLengthNonUniformity, dtype: float64
# ** 5 smalles values: **
# PatientID
# 188    503.361305
# 394    608.356846
# 331    634.663578
# 24     636.531534
# 115    637.142839
# Name: original_glrlm_RunLengthNonUniformity, dtype: float64
# ** 5 highest values: **
# PatientID
# 84     267812.272378
# 48     205566.497796
# 23     158405.539844
# 269    149359.216155
# 30     125783.285418
# Name: original_glrlm_RunLengthNonUniformity, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glrlm_RunPercentage #######
# count    300.000000
# mean       0.770259
# std        0.139863
# min        0.420690
# 25%        0.653939
# 50%        0.793196
# 75%        0.903259
# max        0.960043
# Name: original_glrlm_RunPercentage, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_RunPercentage, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 303    0.420690
# 204    0.422920
# 37     0.423142
# 367    0.434619
# 107    0.451972
# Name: original_glrlm_RunPercentage, dtype: float64
# ** 5 highest values: **
# PatientID
# 143    0.960043
# 362    0.958491
# 121    0.957828
# 321    0.953419
# 244    0.952037
# Name: original_glrlm_RunPercentage, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glrlm_LowGrayLevelRunEmphasis #######
# count    300.000000
# mean       0.004949
# std        0.008117
# min        0.000636
# 25%        0.001541
# 50%        0.002709
# 75%        0.005065
# max        0.095065
# Name: original_glrlm_LowGrayLevelRunEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 116    0.032465
# 39     0.029270
# 331    0.061228
# 282    0.095065
# 25     0.029861
# 72     0.043252
# Name: original_glrlm_LowGrayLevelRunEmphasis, dtype: float64
# ** 5 smalles values: **
# PatientID
# 373    0.000636
# 107    0.000649
# 367    0.000660
# 90     0.000661
# 316    0.000716
# Name: original_glrlm_LowGrayLevelRunEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 282    0.095065
# 331    0.061228
# 72     0.043252
# 116    0.032465
# 25     0.029861
# Name: original_glrlm_LowGrayLevelRunEmphasis, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glrlm_HighGrayLevelRunEmphasis #######
# count     300.000000
# mean     1053.341229
# std       367.251140
# min       259.345076
# 25%       790.854216
# 50%      1048.240239
# 75%      1323.465451
# max      1960.134253
# Name: original_glrlm_HighGrayLevelRunEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_HighGrayLevelRunEmphasis, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 409    259.345076
# 193    287.120167
# 211    335.513265
# 58     357.779869
# 188    359.406191
# Name: original_glrlm_HighGrayLevelRunEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 107    1960.134253
# 90     1885.019240
# 33     1845.892621
# 96     1837.974760
# 173    1798.438936
# Name: original_glrlm_HighGrayLevelRunEmphasis, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glrlm_ShortRunLowGrayLevelEmphasis #######
# count    300.000000
# mean       0.004411
# std        0.006535
# min        0.000401
# 25%        0.001333
# 50%        0.002490
# 75%        0.004650
# max        0.069937
# Name: original_glrlm_ShortRunLowGrayLevelEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 39     0.027730
# 331    0.047230
# 282    0.069937
# 25     0.027067
# 72     0.037878
# Name: original_glrlm_ShortRunLowGrayLevelEmphasis, dtype: float64
# ** 5 smalles values: **
# PatientID
# 367    0.000401
# 107    0.000423
# 373    0.000454
# 90     0.000482
# 145    0.000549
# Name: original_glrlm_ShortRunLowGrayLevelEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 282    0.069937
# 331    0.047230
# 72     0.037878
# 39     0.027730
# 25     0.027067
# Name: original_glrlm_ShortRunLowGrayLevelEmphasis, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glrlm_ShortRunHighGrayLevelEmphasis #######
# count     300.000000
# mean      842.425719
# std       257.999681
# min       245.062735
# 25%       657.397218
# 50%       850.097187
# 75%      1017.454004
# max      1621.293515
# Name: original_glrlm_ShortRunHighGrayLevelEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 423    1621.293515
# Name: original_glrlm_ShortRunHighGrayLevelEmphasis, dtype: float64
# ** 5 smalles values: **
# PatientID
# 409    245.062735
# 193    271.589322
# 211    317.187125
# 188    334.771821
# 58     335.063332
# Name: original_glrlm_ShortRunHighGrayLevelEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 423    1621.293515
# 96     1501.611959
# 33     1448.794260
# 48     1408.597312
# 23     1383.767265
# Name: original_glrlm_ShortRunHighGrayLevelEmphasis, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glrlm_LongRunLowGrayLevelEmphasis #######
# count    300.000000
# mean       0.009939
# std        0.025015
# min        0.001749
# 25%        0.003539
# 50%        0.004787
# 75%        0.007573
# max        0.282310
# Name: original_glrlm_LongRunLowGrayLevelEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 116    0.127769
# 331    0.169757
# 282    0.282310
# 414    0.220645
# 56     0.112182
# Name: original_glrlm_LongRunLowGrayLevelEmphasis, dtype: float64
# ** 5 smalles values: **
# PatientID
# 48     0.001749
# 33     0.002087
# 185    0.002105
# 366    0.002128
# 386    0.002136
# Name: original_glrlm_LongRunLowGrayLevelEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 282    0.282310
# 414    0.220645
# 331    0.169757
# 116    0.127769
# 56     0.112182
# Name: original_glrlm_LongRunLowGrayLevelEmphasis, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: original_glrlm_LongRunHighGrayLevelEmphasis #######
# count      300.000000
# mean      3956.614366
# std       3721.271813
# min        325.511805
# 25%       1396.425566
# 50%       2566.288530
# 75%       5583.538887
# max      25570.594397
# Name: original_glrlm_LongRunHighGrayLevelEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 37     25570.594397
# 303    18595.861384
# 367    18163.095304
# 388    15975.433093
# 107    19593.144133
# 204    16567.527939
# 216    15812.053791
# Name: original_glrlm_LongRunHighGrayLevelEmphasis, dtype: float64
# ** 5 smalles values: **
# PatientID
# 409    325.511805
# 193    361.256631
# 211    424.625577
# 25     431.024025
# 58     467.725694
# Name: original_glrlm_LongRunHighGrayLevelEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 37     25570.594397
# 107    19593.144133
# 303    18595.861384
# 367    18163.095304
# 204    16567.527939
# Name: original_glrlm_LongRunHighGrayLevelEmphasis, dtype: float64
# ** Number of NA: **
# 0
#
# ####### Feature: SurvivalTime #######
# count     300.000000
# mean      867.056667
# std       723.538139
# min        14.000000
# 25%       302.500000
# 50%       644.000000
# 75%      1298.500000
# max      3500.000000
# Name: SurvivalTime, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# PatientID
# 380    3500
# 275    3251
# 297    3078
# 11     3222
# 58     3259
# Name: SurvivalTime, dtype: int64
# ** 5 smalles values: **
# PatientID
# 147    14
# 242    20
# 277    21
# 294    24
# 316    25
# Name: SurvivalTime, dtype: int64
# ** 5 highest values: **
# PatientID
# 380    3500
# 58     3259
# 275    3251
# 11     3222
# 297    3078
# Name: SurvivalTime, dtype: int64
# ** Number of NA: **
# 0
#
# ####### Feature: Event #######
# count    300.00000
# mean       0.54000
# std        0.49923
# min        0.00000
# 25%        0.00000
# 50%        1.00000
# 75%        1.00000
# max        1.00000
# Name: Event, dtype: float64
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: Event, dtype: int64)
# ** 5 smalles values: **
# PatientID
# 202    0
# 240    0
# 284    0
# 372    0
# 394    0
# Name: Event, dtype: int64
# ** 5 highest values: **
# PatientID
# 371    1
# 246    1
# 348    1
# 384    1
# 244    1
# Name: Event, dtype: int64
# ** Number of NA: **
# 0

# %% [markdown]
# ### Conclusions:
# - For Histology, we need to rename some values
# - for the NA in Histology: we will create columns for each category, so we don't have to anything for the NA
# - for the NA in age: we will take the mean (so 0 after standardizing).
# - for the outliers: it is difficult to differenciate extreme values and errors without an expert. We keep all the data.
# - As written in the challenge those data may be biased and may contain errors, so let's use calculated data instead when we can
# - Some values may suggest we should take their log

# %% [markdown]
# ### Checking calculated features

# %%
calculatedTrainingSet=calculateRadiomics('Training')
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %%
checkData(calculatedTrainingSet)
# Out:
# ####### Feature: original_firstorder_10Percentile #######
# count    2.950000e+02
# mean     2.684999e-17
# std      1.000000e+00
# min     -1.914062e+00
# 25%     -8.940972e-01
# 50%     -3.831146e-02
# 75%      8.082920e-01
# max      1.805484e+00
# Name: original_firstorder_10Percentile, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_10Percentile, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 331   -1.914062
# 116   -1.860070
# 72    -1.841705
# 39    -1.793958
# 25    -1.661733
# Name: original_firstorder_10Percentile, dtype: float64
# ** 5 highest values: **
# PatientID
# 107    1.805484
# 5      1.805484
# 367    1.757737
# 90     1.735699
# 397    1.651223
# Name: original_firstorder_10Percentile, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_90Percentile #######
# count    2.950000e+02
# mean    -4.497344e-17
# std      1.000000e+00
# min     -6.291500e+00
# 25%     -1.169680e-01
# 50%      8.720692e-02
# 75%      4.110706e-01
# max      4.480488e+00
# Name: original_firstorder_90Percentile, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_90Percentile, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 193   -6.291500
# 409   -5.911312
# 25    -4.376480
# 211   -4.101900
# 32    -3.517537
# Name: original_firstorder_90Percentile, dtype: float64
# ** 5 highest values: **
# PatientID
# 4     4.480488
# 96    3.720113
# 26    1.664282
# 90    1.326338
# 98    1.284094
# Name: original_firstorder_90Percentile, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_Energy #######
# count    2.950000e+02
# mean    -4.412666e-17
# std      1.000000e+00
# min     -5.464456e-01
# 25%     -4.398466e-01
# 50%     -3.324665e-01
# 75%      5.570762e-02
# max      8.894396e+00
# Name: original_firstorder_Energy, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Energy, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 93    -0.546446
# 418   -0.543021
# 380   -0.542066
# 138   -0.541755
# 11    -0.540814
# Name: original_firstorder_Energy, dtype: float64
# ** 5 highest values: **
# PatientID
# 414    8.894396
# 84     8.574358
# 21     3.356318
# 159    3.344488
# 354    2.974003
# Name: original_firstorder_Energy, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_Entropy #######
# count    2.950000e+02
# mean    -4.936541e-15
# std      1.000000e+00
# min     -2.392098e+00
# 25%     -7.739889e-01
# 50%      1.759451e-01
# 75%      8.721187e-01
# max      1.519493e+00
# Name: original_firstorder_Entropy, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Entropy, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 5     -2.392098
# 204   -2.336447
# 367   -2.176808
# 303   -2.138903
# 388   -2.106587
# Name: original_firstorder_Entropy, dtype: float64
# ** 5 highest values: **
# PatientID
# 244    1.519493
# 72     1.480808
# 82     1.471352
# 197    1.458932
# 151    1.450285
# Name: original_firstorder_Entropy, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_InterquartileRange #######
# count    2.950000e+02
# mean    -1.334149e-16
# std      1.000000e+00
# min     -1.225336e+00
# 25%     -9.574149e-01
# 50%     -1.292956e-01
# 75%      7.694574e-01
# max      2.691181e+00
# Name: original_firstorder_InterquartileRange, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_InterquartileRange, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 204   -1.225336
# 5     -1.215593
# 37    -1.210722
# 216   -1.210722
# 388   -1.205851
# Name: original_firstorder_InterquartileRange, dtype: float64
# ** 5 highest values: **
# PatientID
# 72     2.691181
# 53     2.447617
# 195    2.320963
# 244    2.167518
# 282    2.112716
# Name: original_firstorder_InterquartileRange, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_Kurtosis #######
# count    2.950000e+02
# mean    -6.749780e-16
# std      1.000000e+00
# min     -5.065451e-01
# 25%     -4.515467e-01
# 50%     -3.579919e-01
# 75%      3.093057e-02
# max      8.800760e+00
# Name: original_firstorder_Kurtosis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Kurtosis, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 195   -0.506545
# 375   -0.494118
# 47    -0.493856
# 277   -0.493751
# 273   -0.493072
# Name: original_firstorder_Kurtosis, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     8.800760
# 107    6.713471
# 173    5.316981
# 367    5.261486
# 5      3.535820
# Name: original_firstorder_Kurtosis, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_Maximum #######
# count    2.950000e+02
# mean     1.204310e-17
# std      1.000000e+00
# min     -1.188638e+00
# 25%     -6.406210e-01
# 50%     -3.409044e-01
# 75%      2.698150e-01
# max      6.684250e+00
# Name: original_firstorder_Maximum, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Maximum, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 409   -1.188638
# 304   -0.960402
# 105   -0.957894
# 305   -0.930305
# 148   -0.920273
# Name: original_firstorder_Maximum, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     6.684250
# 134    5.761274
# 98     4.296550
# 112    2.927134
# 106    2.628672
# Name: original_firstorder_Maximum, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_MeanAbsoluteDeviation #######
# count    2.950000e+02
# mean     5.513774e-16
# std      1.000000e+00
# min     -1.704274e+00
# 25%     -7.855736e-01
# 50%     -2.243568e-02
# 75%      7.128345e-01
# max      2.463787e+00
# Name: original_firstorder_MeanAbsoluteDeviation, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_MeanAbsoluteDeviation, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367   -1.704274
# 204   -1.682829
# 5     -1.672715
# 107   -1.672135
# 110   -1.627287
# Name: original_firstorder_MeanAbsoluteDeviation, dtype: float64
# ** 5 highest values: **
# PatientID
# 72     2.463787
# 282    2.284198
# 53     2.138665
# 183    2.093835
# 333    2.086687
# Name: original_firstorder_MeanAbsoluteDeviation, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_Mean #######
# count    2.950000e+02
# mean    -4.198148e-16
# std      1.000000e+00
# min     -3.121493e+00
# 25%     -6.842955e-01
# 50%      2.294754e-01
# 75%      8.018225e-01
# max      1.501519e+00
# Name: original_firstorder_Mean, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Mean, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 193   -3.121493
# 409   -3.073104
# 39    -3.071610
# 25    -2.845533
# 70    -2.785822
# Name: original_firstorder_Mean, dtype: float64
# ** 5 highest values: **
# PatientID
# 4      1.501519
# 90     1.463648
# 107    1.436257
# 367    1.366278
# 5      1.357892
# Name: original_firstorder_Mean, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_Median #######
# count    2.950000e+02
# mean     5.268855e-17
# std      1.000000e+00
# min     -3.435067e+00
# 25%     -4.726092e-01
# 50%      5.027710e-01
# 75%      6.947341e-01
# max      9.904611e-01
# Name: original_firstorder_Median, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Median, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 39    -3.435067
# 409   -3.066705
# 193   -3.014823
# 70    -2.962942
# 282   -2.879930
# Name: original_firstorder_Median, dtype: float64
# ** 5 highest values: **
# PatientID
# 316    0.990461
# 90     0.969708
# 107    0.964520
# 26     0.943767
# 358    0.943767
# Name: original_firstorder_Median, dtype: float64
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_Minimum #######
# count    2.950000e+02
# mean    -3.026769e-16
# std      1.000000e+00
# min     -2.269890e+00
# 25%     -8.638490e-01
# 50%     -2.558312e-01
# 75%      6.989467e-01
# max      4.579810e+00
# Name: original_firstorder_Minimum, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Minimum, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 88    -2.269890
# 244   -0.987353
# 423   -0.987353
# 197   -0.987353
# 53    -0.987353
# Name: original_firstorder_Minimum, dtype: float64
# ** 5 highest values: **
# PatientID
# 93     4.579810
# 110    4.066795
# 418    3.021764
# 100    2.689255
# 73     2.499249
# Name: original_firstorder_Minimum, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_Range #######
# count    2.950000e+02
# mean    -3.217765e-17
# std      1.000000e+00
# min     -1.815498e+00
# 25%     -6.918296e-01
# 50%     -2.042876e-01
# 75%      4.155873e-01
# max      6.300916e+00
# Name: original_firstorder_Range, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Range, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 93    -1.815498
# 73    -1.325634
# 303   -1.230447
# 325   -1.211874
# 110   -1.186336
# Name: original_firstorder_Range, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     6.300916
# 134    5.555673
# 98     4.218415
# 84     2.665245
# 242    2.618813
# Name: original_firstorder_Range, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_RobustMeanAbsoluteDeviation #######
# count    2.950000e+02
# mean    -2.706404e-16
# std      1.000000e+00
# min     -1.361262e+00
# 25%     -9.287895e-01
# 50%     -1.096236e-01
# 75%      7.546517e-01
# max      2.474063e+00
# Name: original_firstorder_RobustMeanAbsoluteDeviation, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_RobustMeanAbsoluteDeviation, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 204   -1.361262
# 5     -1.357149
# 216   -1.336708
# 37    -1.331648
# 388   -1.321949
# Name: original_firstorder_RobustMeanAbsoluteDeviation, dtype: float64
# ** 5 highest values: **
# PatientID
# 72     2.474063
# 195    2.263106
# 53     2.214429
# 333    2.207110
# 183    2.206087
# Name: original_firstorder_RobustMeanAbsoluteDeviation, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_RootMeanSquared #######
# count    2.950000e+02
# mean    -4.045728e-16
# std      1.000000e+00
# min     -1.471478e+00
# 25%     -8.403347e-01
# 50%     -2.089976e-01
# 75%      7.435598e-01
# max      2.885277e+00
# Name: original_firstorder_RootMeanSquared, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_RootMeanSquared, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 110   -1.471478
# 204   -1.442812
# 269   -1.425855
# 93    -1.394710
# 248   -1.394203
# Name: original_firstorder_RootMeanSquared, dtype: float64
# ** 5 highest values: **
# PatientID
# 39     2.885277
# 193    2.685608
# 409    2.622891
# 70     2.531930
# 25     2.531594
# Name: original_firstorder_RootMeanSquared, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_Skewness #######
# count    2.950000e+02
# mean     2.423673e-16
# std      1.000000e+00
# min     -4.350111e+00
# 25%     -5.529271e-01
# 50%      2.111154e-01
# 75%      6.278210e-01
# max      3.846815e+00
# Name: original_firstorder_Skewness, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Skewness, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 107   -4.350111
# 173   -4.286423
# 5     -3.388754
# 367   -3.227827
# 16    -2.935875
# Name: original_firstorder_Skewness, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     3.846815
# 384    1.821485
# 193    1.635919
# 39     1.578343
# 397    1.487983
# Name: original_firstorder_Skewness, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_TotalEnergy #######
# count    2.950000e+02
# mean    -4.412666e-17
# std      1.000000e+00
# min     -5.464456e-01
# 25%     -4.398466e-01
# 50%     -3.324665e-01
# 75%      5.570762e-02
# max      8.894396e+00
# Name: original_firstorder_TotalEnergy, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_TotalEnergy, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 93    -0.546446
# 418   -0.543021
# 380   -0.542066
# 138   -0.541755
# 11    -0.540814
# Name: original_firstorder_TotalEnergy, dtype: float64
# ** 5 highest values: **
# PatientID
# 414    8.894396
# 84     8.574358
# 21     3.356318
# 159    3.344488
# 354    2.974003
# Name: original_firstorder_TotalEnergy, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_Uniformity #######
# count    2.950000e+02
# mean    -5.627325e-16
# std      1.000000e+00
# min     -1.031242e+00
# 25%     -8.431265e-01
# 50%     -3.379867e-01
# 75%      6.156196e-01
# max      3.722796e+00
# Name: original_firstorder_Uniformity, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Uniformity, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 244   -1.031242
# 197   -1.029083
# 82    -1.022709
# 151   -1.016712
# 323   -1.016679
# Name: original_firstorder_Uniformity, dtype: float64
# ** 5 highest values: **
# PatientID
# 303    3.722796
# 5      3.086276
# 204    3.071056
# 216    2.754679
# 388    2.674473
# Name: original_firstorder_Uniformity, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_firstorder_Variance #######
# count    2.950000e+02
# mean     1.921250e-16
# std      1.000000e+00
# min     -1.352932e+00
# 25%     -8.165512e-01
# 50%     -1.870808e-01
# 75%      6.076720e-01
# max      3.433601e+00
# Name: original_firstorder_Variance, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_firstorder_Variance, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367   -1.352932
# 110   -1.338573
# 204   -1.311136
# 269   -1.300792
# 107   -1.298426
# Name: original_firstorder_Variance, dtype: float64
# ** 5 highest values: **
# PatientID
# 72     3.433601
# 282    3.249739
# 53     2.745460
# 183    2.505534
# 333    2.474833
# Name: original_firstorder_Variance, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_Elongation #######
# count    2.950000e+02
# mean     2.594158e-15
# std      1.000000e+00
# min     -3.086450e+00
# 25%     -6.632805e-01
# 50%      1.254542e-01
# 75%      7.825400e-01
# max      1.580191e+00
# Name: original_shape_Elongation, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_Elongation, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 304   -3.086450
# 144   -2.885352
# 154   -2.883105
# 306   -2.779775
# 138   -2.760423
# Name: original_shape_Elongation, dtype: float64
# ** 5 highest values: **
# PatientID
# 114    1.580191
# 358    1.562924
# 135    1.552029
# 53     1.544612
# 39     1.536385
# Name: original_shape_Elongation, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_Flatness #######
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
# count    2.950000e+02
# mean     3.086044e-17
# std      1.000000e+00
# min     -2.624975e+00
# 25%     -6.060535e-01
# 50%      7.475499e-02
# 75%      7.003257e-01
# max      2.237035e+00
# Name: original_shape_Flatness, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_Flatness, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 102   -2.624975
# 318   -2.486880
# 277   -2.486117
# 145   -2.462336
# 362   -2.388510
# Name: original_shape_Flatness, dtype: float64
# ** 5 highest values: **
# PatientID
# 401    2.237035
# 157    2.119225
# 299    1.949813
# 346    1.823917
# 101    1.798621
# Name: original_shape_Flatness, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_LeastAxisLength #######
# count    2.950000e+02
# mean    -4.817239e-16
# std      1.000000e+00
# min     -1.422539e+00
# 25%     -8.172023e-01
# 50%     -1.888433e-01
# 75%      6.364340e-01
# max      3.063172e+00
# Name: original_shape_LeastAxisLength, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_LeastAxisLength, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 362   -1.422539
# 138   -1.416937
# 24    -1.399023
# 149   -1.372250
# 63    -1.370899
# Name: original_shape_LeastAxisLength, dtype: float64
# ** 5 highest values: **
# PatientID
# 48     3.063172
# 159    2.763987
# 107    2.731997
# 401    2.654337
# 124    2.619408
# Name: original_shape_LeastAxisLength, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_MajorAxisLength #######
# count    2.950000e+02
# mean    -7.216450e-17
# std      1.000000e+00
# min     -1.445432e+00
# 25%     -8.515701e-01
# 50%     -2.151504e-01
# 75%      6.408510e-01
# max      3.200182e+00
# Name: original_shape_MajorAxisLength, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_MajorAxisLength, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 115   -1.445432
# 188   -1.425830
# 325   -1.356114
# 394   -1.353719
# 381   -1.346932
# Name: original_shape_MajorAxisLength, dtype: float64
# ** 5 highest values: **
# PatientID
# 102    3.200182
# 145    2.776425
# 355    2.674478
# 316    2.378836
# 269    2.327633
# Name: original_shape_MajorAxisLength, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_Maximum2DDiameterColumn #######
# count    2.950000e+02
# mean    -1.463989e-15
# std      1.000000e+00
# min     -1.491348e+00
# 25%     -8.572609e-01
# 50%     -1.736764e-01
# 75%      7.340542e-01
# max      2.703643e+00
# Name: original_shape_Maximum2DDiameterColumn, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_Maximum2DDiameterColumn, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 188   -1.491348
# 115   -1.413147
# 11    -1.402803
# 280   -1.354031
# 394   -1.352868
# Name: original_shape_Maximum2DDiameterColumn, dtype: float64
# ** 5 highest values: **
# PatientID
# 269    2.703643
# 84     2.629277
# 367    2.452266
# 224    2.414322
# 124    2.407867
# Name: original_shape_Maximum2DDiameterColumn, dtype: float64
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_Maximum2DDiameterRow #######
# count    2.950000e+02
# mean     9.647532e-16
# std      1.000000e+00
# min     -1.539596e+00
# 25%     -8.371110e-01
# 50%     -1.646528e-01
# 75%      6.889335e-01
# max      2.715979e+00
# Name: original_shape_Maximum2DDiameterRow, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_Maximum2DDiameterRow, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 188   -1.539596
# 394   -1.531591
# 115   -1.520601
# 149   -1.461957
# 24    -1.459186
# Name: original_shape_Maximum2DDiameterRow, dtype: float64
# ** 5 highest values: **
# PatientID
# 355    2.715979
# 249    2.669795
# 269    2.368649
# 84     2.213049
# 294    2.058702
# Name: original_shape_Maximum2DDiameterRow, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_Maximum2DDiameterSlice #######
# count    2.950000e+02
# mean     6.122692e-16
# std      1.000000e+00
# min     -1.519984e+00
# 25%     -9.027561e-01
# 50%     -1.811577e-01
# 75%      7.195817e-01
# max      2.535502e+00
# Name: original_shape_Maximum2DDiameterSlice, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_Maximum2DDiameterSlice, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 331   -1.519984
# 115   -1.441162
# 188   -1.430735
# 381   -1.406807
# 394   -1.361974
# Name: original_shape_Maximum2DDiameterSlice, dtype: float64
# ** 5 highest values: **
# PatientID
# 316    2.535502
# 355    2.324725
# 269    2.302175
# 124    2.201429
# 367    2.187415
# Name: original_shape_Maximum2DDiameterSlice, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_Maximum3DDiameter #######
# count    2.950000e+02
# mean     1.007669e-15
# std      1.000000e+00
# min     -1.518218e+00
# 25%     -8.909969e-01
# 50%     -1.470436e-01
# 75%      6.502210e-01
# max      2.668007e+00
# Name: original_shape_Maximum3DDiameter, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_Maximum3DDiameter, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 115   -1.518218
# 188   -1.506706
# 394   -1.419699
# 63    -1.417799
# 11    -1.408400
# Name: original_shape_Maximum3DDiameter, dtype: float64
# ** 5 highest values: **
# PatientID
# 355    2.668007
# 269    2.613192
# 145    2.474395
# 367    2.288984
# 4      2.242565
# Name: original_shape_Maximum3DDiameter, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_MeshVolume #######
# count    2.950000e+02
# mean     2.469893e-16
# std      1.000000e+00
# min     -6.900746e-01
# 25%     -6.276184e-01
# 50%     -4.424731e-01
# 75%      1.702880e-01
# max      5.012028e+00
# Name: original_shape_MeshVolume, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_MeshVolume, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 188   -0.690075
# 24    -0.689229
# 394   -0.689108
# 115   -0.688887
# 381   -0.688391
# Name: original_shape_MeshVolume, dtype: float64
# ** 5 highest values: **
# PatientID
# 269    5.012028
# 107    4.328871
# 48     4.006486
# 159    3.869283
# 84     3.561008
# Name: original_shape_MeshVolume, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_MinorAxisLength #######
# count    2.950000e+02
# mean     9.101947e-16
# std      1.000000e+00
# min     -1.438730e+00
# 25%     -8.565939e-01
# 50%     -2.126805e-01
# 75%      6.532185e-01
# max      2.984567e+00
# Name: original_shape_MinorAxisLength, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_MinorAxisLength, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 138   -1.438730
# 331   -1.425144
# 188   -1.403718
# 394   -1.396298
# 115   -1.375538
# Name: original_shape_MinorAxisLength, dtype: float64
# ** 5 highest values: **
# PatientID
# 269    2.984567
# 84     2.697699
# 124    2.429364
# 159    2.407026
# 355    2.374796
# Name: original_shape_MinorAxisLength, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_Sphericity #######
# count    2.950000e+02
# mean     1.274687e-15
# std      1.000000e+00
# min     -3.182249e+00
# 25%     -6.188735e-01
# 50%      5.135235e-02
# 75%      7.404994e-01
# max      2.464014e+00
# Name: original_shape_Sphericity, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_Sphericity, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 277   -3.182249
# 102   -2.656364
# 142   -2.560785
# 43    -2.541521
# 145   -2.488350
# Name: original_shape_Sphericity, dtype: float64
# ** 5 highest values: **
# PatientID
# 188    2.464014
# 11     1.993386
# 22     1.944076
# 394    1.909920
# 141    1.860113
# Name: original_shape_Sphericity, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_SurfaceArea #######
# count    2.950000e+02
# mean     2.500589e-16
# std      1.000000e+00
# min     -9.431219e-01
# 25%     -7.689337e-01
# 50%     -4.197563e-01
# 75%      4.053848e-01
# max      4.569028e+00
# Name: original_shape_SurfaceArea, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_SurfaceArea, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 188   -0.943122
# 394   -0.936958
# 115   -0.935293
# 331   -0.930931
# 24    -0.929368
# Name: original_shape_SurfaceArea, dtype: float64
# ** 5 highest values: **
# PatientID
# 84     4.569028
# 23     3.360503
# 269    3.128101
# 124    3.114688
# 48     3.099751
# Name: original_shape_SurfaceArea, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_SurfaceVolumeRatio #######
# count    2.950000e+02
# mean     2.193349e-15
# std      1.000000e+00
# min     -1.432055e+00
# 25%     -7.959825e-01
# 50%     -2.361920e-01
# 75%      5.463810e-01
# max      3.006435e+00
# Name: original_shape_SurfaceVolumeRatio, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_SurfaceVolumeRatio, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 107   -1.432055
# 269   -1.419553
# 159   -1.392307
# 30    -1.328070
# 48    -1.305892
# Name: original_shape_SurfaceVolumeRatio, dtype: float64
# ** 5 highest values: **
# PatientID
# 121    3.006435
# 149    2.929880
# 24     2.689931
# 362    2.663328
# 290    2.658244
# Name: original_shape_SurfaceVolumeRatio, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_shape_VoxelVolume #######
# count    2.950000e+02
# mean     9.996712e-18
# std      1.000000e+00
# min     -6.905269e-01
# 25%     -6.277503e-01
# 50%     -4.421229e-01
# 75%      1.710346e-01
# max      5.010885e+00
# Name: original_shape_VoxelVolume, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_shape_VoxelVolume, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 188   -0.690527
# 24    -0.689635
# 394   -0.689533
# 115   -0.689303
# 381   -0.688768
# Name: original_shape_VoxelVolume, dtype: float64
# ** 5 highest values: **
# PatientID
# 269    5.010885
# 107    4.327819
# 48     4.006217
# 159    3.868336
# 84     3.561292
# Name: original_shape_VoxelVolume, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_Autocorrelation #######
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# count    2.950000e+02
# mean    -2.675826e-15
# std      1.000000e+00
# min     -2.255235e+00
# 25%     -7.727469e-01
# 50%      4.735230e-04
# 75%      7.744959e-01
# max      2.214413e+00
# Name: original_glcm_Autocorrelation, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_Autocorrelation, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 409   -2.255235
# 193   -2.217960
# 188   -2.140407
# 211   -2.061069
# 25    -2.037715
# Name: original_glcm_Autocorrelation, dtype: float64
# ** 5 highest values: **
# PatientID
# 107    2.214413
# 316    2.101187
# 96     1.975094
# 33     1.886438
# 90     1.828878
# Name: original_glcm_Autocorrelation, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_ClusterProminence #######
# count    2.950000e+02
# mean     6.797764e-16
# std      1.000000e+00
# min     -9.615561e-01
# 25%     -6.669162e-01
# 50%     -2.925859e-01
# 75%      3.337397e-01
# max      7.236781e+00
# Name: original_glcm_ClusterProminence, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_ClusterProminence, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 110   -0.961556
# 93    -0.953963
# 367   -0.946514
# 247   -0.940708
# 248   -0.935102
# Name: original_glcm_ClusterProminence, dtype: float64
# ** 5 highest values: **
# PatientID
# 282    7.236781
# 414    5.079076
# 116    4.390067
# 72     4.194714
# 294    2.768676
# Name: original_glcm_ClusterProminence, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_ClusterShade #######
# count    2.950000e+02
# mean    -2.483889e-16
# std      1.000000e+00
# min     -5.111636e+00
# 25%     -3.824635e-01
# 50%      1.102069e-01
# 75%      4.905851e-01
# max      6.877433e+00
# Name: original_glcm_ClusterShade, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_ClusterShade, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 414   -5.111636
# 116   -3.955438
# 294   -3.141172
# 30    -2.454890
# 354   -2.204426
# Name: original_glcm_ClusterShade, dtype: float64
# ** 5 highest values: **
# PatientID
# 282    6.877433
# 78     3.553416
# 39     3.040548
# 72     2.436779
# 70     1.695018
# Name: original_glcm_ClusterShade, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_ClusterTendency #######
# count    2.950000e+02
# mean    -4.299762e-17
# std      1.000000e+00
# min     -1.290246e+00
# 25%     -7.944422e-01
# 50%     -1.917221e-01
# 75%      6.263168e-01
# max      3.884327e+00
# Name: original_glcm_ClusterTendency, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_ClusterTendency, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367   -1.290246
# 110   -1.278553
# 204   -1.256642
# 269   -1.248161
# 248   -1.242699
# Name: original_glcm_ClusterTendency, dtype: float64
# ** 5 highest values: **
# PatientID
# 72     3.884327
# 282    3.531043
# 116    3.052895
# 53     2.885350
# 333    2.575166
# Name: original_glcm_ClusterTendency, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_Contrast #######
# count    2.950000e+02
# mean    -3.466154e-16
# std      1.000000e+00
# min     -9.231874e-01
# 25%     -6.830643e-01
# 50%     -4.128497e-01
# 75%      2.688166e-01
# max      3.920316e+00
# Name: original_glcm_Contrast, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_Contrast, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367   -0.923187
# 204   -0.906121
# 107   -0.905558
# 16    -0.900487
# 110   -0.894940
# Name: original_glcm_Contrast, dtype: float64
# ** 5 highest values: **
# PatientID
# 244    3.920316
# 390    3.656592
# 368    3.378776
# 151    2.980039
# 279    2.885460
# Name: original_glcm_Contrast, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_Correlation #######
# count    2.950000e+02
# mean     2.491416e-16
# std      1.000000e+00
# min     -4.147222e+00
# 25%     -5.208477e-01
# 50%      2.097611e-01
# 75%      7.316662e-01
# max      1.593619e+00
# Name: original_glcm_Correlation, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_Correlation, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 280   -4.147222
# 381   -3.117660
# 390   -2.976652
# 258   -2.955922
# 77    -2.845110
# Name: original_glcm_Correlation, dtype: float64
# ** 5 highest values: **
# PatientID
# 294    1.593619
# 78     1.590350
# 282    1.590306
# 414    1.555074
# 159    1.517355
# Name: original_glcm_Correlation, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_DifferenceAverage #######
# count    2.950000e+02
# mean    -7.703819e-16
# std      1.000000e+00
# min     -1.367741e+00
# 25%     -7.973018e-01
# 50%     -2.733518e-01
# 75%      6.181227e-01
# max      2.923207e+00
# Name: original_glcm_DifferenceAverage, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_DifferenceAverage, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367   -1.367741
# 204   -1.323303
# 107   -1.315093
# 5     -1.282167
# 388   -1.211087
# Name: original_glcm_DifferenceAverage, dtype: float64
# ** 5 highest values: **
# PatientID
# 244    2.923207
# 390    2.753528
# 368    2.480917
# 121    2.418439
# 151    2.397659
# Name: original_glcm_DifferenceAverage, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_DifferenceEntropy #######
# count    2.950000e+02
# mean    -5.511599e-16
# std      1.000000e+00
# min     -2.239257e+00
# 25%     -7.855335e-01
# 50%     -1.940366e-04
# 75%      7.928719e-01
# max      2.021797e+00
# Name: original_glcm_DifferenceEntropy, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_DifferenceEntropy, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367   -2.239257
# 204   -2.029295
# 107   -2.025060
# 5     -1.955734
# 16    -1.719121
# Name: original_glcm_DifferenceEntropy, dtype: float64
# ** 5 highest values: **
# PatientID
# 244    2.021797
# 390    1.935033
# 151    1.813184
# 368    1.809659
# 121    1.765589
# Name: original_glcm_DifferenceEntropy, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_DifferenceVariance #######
# count    2.950000e+02
# mean     5.581223e-16
# std      1.000000e+00
# min     -9.718533e-01
# 25%     -6.410313e-01
# 50%     -3.940122e-01
# 75%      1.730367e-01
# max      3.662265e+00
# Name: original_glcm_DifferenceVariance, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_DifferenceVariance, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367   -0.971853
# 16    -0.954541
# 107   -0.942896
# 110   -0.942754
# 204   -0.942743
# Name: original_glcm_DifferenceVariance, dtype: float64
# ** 5 highest values: **
# PatientID
# 244    3.662265
# 368    3.526102
# 390    3.513060
# 174    3.389994
# 279    3.255613
# Name: original_glcm_DifferenceVariance, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_Id #######
# count    2.950000e+02
# mean     9.215792e-17
# std      1.000000e+00
# min     -1.656009e+00
# 25%     -9.331568e-01
# 50%      2.095154e-02
# 75%      8.608366e-01
# max      2.086468e+00
# Name: original_glcm_Id, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_Id, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 244   -1.656009
# 143   -1.653318
# 121   -1.616190
# 321   -1.587122
# 362   -1.582037
# Name: original_glcm_Id, dtype: float64
# ** 5 highest values: **
# PatientID
# 367    2.086468
# 204    2.036529
# 37     1.959060
# 107    1.926143
# 5      1.917613
# Name: original_glcm_Id, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_Idm #######
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# count    2.950000e+02
# mean    -1.328739e-16
# std      1.000000e+00
# min     -1.609091e+00
# 25%     -9.229728e-01
# 50%      7.081831e-03
# 75%      8.712352e-01
# max      2.100640e+00
# Name: original_glcm_Idm, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_Idm, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 143   -1.609091
# 244   -1.559707
# 321   -1.556927
# 362   -1.553483
# 121   -1.550919
# Name: original_glcm_Idm, dtype: float64
# ** 5 highest values: **
# PatientID
# 367    2.100640
# 204    2.036098
# 37     1.942168
# 107    1.939406
# 5      1.933086
# Name: original_glcm_Idm, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_Idmn #######
# count    2.950000e+02
# mean    -3.217878e-14
# std      1.000000e+00
# min     -4.004565e+00
# 25%     -5.829172e-01
# 50%      3.707712e-01
# 75%      8.151413e-01
# max      1.034909e+00
# Name: original_glcm_Idmn, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glcm_Idmn, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 394   -4.004565
# 290   -3.124100
# 390   -3.100525
# 368   -2.969581
# 115   -2.918420
# Name: original_glcm_Idmn, dtype: float64
# ** 5 highest values: **
# PatientID
# 90     1.034909
# 367    1.021139
# 204    1.017658
# 248    1.015240
# 397    1.013885
# Name: original_glcm_Idmn, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glcm_Idn #######
# count    2.950000e+02
# mean    -9.489208e-15
# ...
# ** 5 smalles values: **
# PatientID
# 143   -0.818235
# 362   -0.815150
# 121   -0.814475
# 321   -0.806985
# 163   -0.805098
# Name: original_glrlm_LongRunEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 303    7.149059
# 37     4.765032
# 204    4.587993
# 367    3.765831
# 388    3.284142
# Name: original_glrlm_LongRunEmphasis, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glrlm_LongRunHighGrayLevelEmphasis #######
# count    2.950000e+02
# mean     6.256765e-16
# std      1.000000e+00
# min     -9.653819e-01
# 25%     -6.844688e-01
# 50%     -3.702813e-01
# 75%      3.829318e-01
# max      5.613855e+00
# Name: original_glrlm_LongRunHighGrayLevelEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_LongRunHighGrayLevelEmphasis, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 409   -0.965382
# 193   -0.955916
# 188   -0.943916
# 211   -0.939135
# 25    -0.937441
# Name: original_glrlm_LongRunHighGrayLevelEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 37     5.613855
# 107    4.323739
# 367    4.104081
# 303    3.833495
# 204    3.516534
# Name: original_glrlm_LongRunHighGrayLevelEmphasis, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glrlm_LongRunLowGrayLevelEmphasis #######
# count    2.950000e+02
# mean    -1.392483e-16
# std      1.000000e+00
# min     -3.465121e-01
# 25%     -2.681653e-01
# 50%     -2.238733e-01
# 75%     -8.997485e-02
# max      1.017039e+01
# Name: original_glrlm_LongRunLowGrayLevelEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_LongRunLowGrayLevelEmphasis, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 48    -0.346512
# 33    -0.335569
# 185   -0.330888
# 386   -0.329523
# 258   -0.327174
# Name: original_glrlm_LongRunLowGrayLevelEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 282    10.170390
# 414     9.481798
# 116     5.150649
# 331     4.498582
# 56      4.420559
# Name: original_glrlm_LongRunLowGrayLevelEmphasis, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glrlm_LowGrayLevelRunEmphasis #######
# count    2.950000e+02
# mean    -3.400293e-16
# std      1.000000e+00
# min     -5.625898e-01
# 25%     -4.451282e-01
# 50%     -3.040820e-01
# 75%      6.220606e-02
# max      1.065285e+01
# Name: original_glrlm_LowGrayLevelRunEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_LowGrayLevelRunEmphasis, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367   -0.562590
# 316   -0.561327
# 107   -0.561292
# 397   -0.560141
# 90    -0.559365
# Name: original_glrlm_LowGrayLevelRunEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 282    10.652847
# 331     5.680994
# 72      5.063559
# 116     3.666656
# 25      3.295592
# Name: original_glrlm_LowGrayLevelRunEmphasis, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glrlm_RunEntropy #######
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# count    2.950000e+02
# mean     1.538412e-15
# std      1.000000e+00
# min     -3.610162e+00
# 25%     -6.057123e-01
# 50%      1.885194e-01
# 75%      6.902474e-01
# max      2.166048e+00
# Name: original_glrlm_RunEntropy, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_RunEntropy, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 173   -3.610162
# 313   -3.064193
# 269   -2.851000
# 16    -2.779441
# 237   -2.605005
# Name: original_glrlm_RunEntropy, dtype: float64
# ** 5 highest values: **
# PatientID
# 414    2.166048
# 96     1.984656
# 259    1.831463
# 52     1.821990
# 4      1.722278
# Name: original_glrlm_RunEntropy, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glrlm_RunLengthNonUniformity #######
# count    2.950000e+02
# mean     1.928777e-16
# std      1.000000e+00
# min     -7.070806e-01
# 25%     -6.030296e-01
# 50%     -3.526881e-01
# 75%      2.246731e-01
# max      7.566927e+00
# Name: original_glrlm_RunLengthNonUniformity, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_RunLengthNonUniformity, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 188   -0.707081
# 24    -0.704213
# 394   -0.704093
# 115   -0.703116
# 138   -0.702819
# Name: original_glrlm_RunLengthNonUniformity, dtype: float64
# ** 5 highest values: **
# PatientID
# 84     7.566927
# 48     6.112331
# 23     4.568363
# 269    3.677327
# 30     3.503544
# Name: original_glrlm_RunLengthNonUniformity, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glrlm_RunLengthNonUniformityNormalized #######
# count    2.950000e+02
# mean    -3.421474e-15
# std      1.000000e+00
# min     -2.490289e+00
# 25%     -8.425923e-01
# 50%      1.076225e-01
# 75%      9.184118e-01
# max      1.478530e+00
# Name: original_glrlm_RunLengthNonUniformityNormalized, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_RunLengthNonUniformityNormalized, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367   -2.490289
# 204   -2.373886
# 107   -2.350096
# 5     -2.101423
# 37    -2.030985
# Name: original_glrlm_RunLengthNonUniformityNormalized, dtype: float64
# ** 5 highest values: **
# PatientID
# 143    1.478530
# 362    1.467049
# 121    1.456062
# 321    1.414282
# 244    1.408680
# Name: original_glrlm_RunLengthNonUniformityNormalized, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glrlm_RunPercentage #######
# count    2.950000e+02
# mean    -4.186670e-15
# std      1.000000e+00
# min     -2.534861e+00
# 25%     -8.173411e-01
# 50%      1.460062e-01
# 75%      9.511029e-01
# max      1.359134e+00
# Name: original_glrlm_RunPercentage, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_RunPercentage, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 204   -2.534861
# 367   -2.487452
# 303   -2.483807
# 37    -2.456626
# 107   -2.317080
# Name: original_glrlm_RunPercentage, dtype: float64
# ** 5 highest values: **
# PatientID
# 143    1.359134
# 362    1.348045
# 121    1.343306
# 321    1.311793
# 244    1.301919
# Name: original_glrlm_RunPercentage, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glrlm_RunVariance #######
# count    2.950000e+02
# mean    -3.424756e-16
# std      1.000000e+00
# min     -7.242886e-01
# 25%     -6.469558e-01
# 50%     -3.516341e-01
# 75%      3.350272e-01
# max      9.060907e+00
# Name: original_glrlm_RunVariance, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_RunVariance, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 143   -0.724289
# 362   -0.721931
# 121   -0.721899
# 321   -0.716589
# 163   -0.715939
# Name: original_glrlm_RunVariance, dtype: float64
# ** 5 highest values: **
# PatientID
# 303    9.060907
# 37     5.070775
# 204    4.389750
# 388    3.255415
# 367    3.153891
# Name: original_glrlm_RunVariance, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glrlm_ShortRunEmphasis #######
# count    2.950000e+02
# mean    -6.320744e-16
# std      1.000000e+00
# min     -3.139265e+00
# 25%     -7.555575e-01
# 50%      1.928978e-01
# 75%      8.948164e-01
# max      1.311155e+00
# Name: original_glrlm_ShortRunEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_ShortRunEmphasis, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367   -3.139265
# 107   -2.881500
# 204   -2.872527
# 5     -2.448371
# 216   -2.295974
# Name: original_glrlm_ShortRunEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 143    1.311155
# 362    1.301941
# 121    1.294475
# 321    1.265576
# 244    1.260862
# Name: original_glrlm_ShortRunEmphasis, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glrlm_ShortRunHighGrayLevelEmphasis #######
# count    2.950000e+02
# mean    -3.096581e-15
# std      1.000000e+00
# min     -2.339359e+00
# 25%     -7.402642e-01
# 50%      4.164994e-02
# 75%      6.934293e-01
# max      3.002234e+00
# Name: original_glrlm_ShortRunHighGrayLevelEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_ShortRunHighGrayLevelEmphasis, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 93    -2.339359
# 409   -2.287001
# 193   -2.185052
# 188   -2.069286
# 211   -2.009807
# Name: original_glrlm_ShortRunHighGrayLevelEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 423    3.002234
# 96     2.654544
# 33     2.310890
# 48     2.213985
# 23     2.107560
# Name: original_glrlm_ShortRunHighGrayLevelEmphasis, dtype: float64
# ** Number of NA: **
# 5
#
# ####### Feature: original_glrlm_ShortRunLowGrayLevelEmphasis #######
# count    2.950000e+02
# mean    -6.887146e-17
# std      1.000000e+00
# min     -6.392985e-01
# 25%     -4.932651e-01
# 50%     -3.125622e-01
# 75%      7.872562e-02
# max      9.646250e+00
# Name: original_glrlm_ShortRunLowGrayLevelEmphasis, dtype: float64
# ** Values for which the Z score is greather than 3 : **
# Series([], Name: original_glrlm_ShortRunLowGrayLevelEmphasis, dtype: float64)
# ** 5 smalles values: **
# PatientID
# 367   -0.639298
# 107   -0.631771
# 397   -0.625086
# 90    -0.623704
# 316   -0.618791
# Name: original_glrlm_ShortRunLowGrayLevelEmphasis, dtype: float64
# ** 5 highest values: **
# PatientID
# 282    9.646250
# 331    5.535885
# 72     5.332049
# 39     3.716263
# 25     3.610674
# Name: original_glrlm_ShortRunLowGrayLevelEmphasis, dtype: float64
# ** Number of NA: **
# 5
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in greater
#
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   del sys.path[0]

# %% [markdown]
# ### Conclusions:
# - We have empty masks; leading to NA values
# - for the outliers: as the data are calculated automatically, we take the assumption we don't have any errors.
# - It is not easy to figure out which calculated feature match the provided feature.

# %% [markdown]
# ### Comparing provided and calculated features
# Let's try to compare provided and calculated features having the same name.

# %%
# We check the features having the same names. We plot them, we also plot an histogram of their differences 
# we used standardized values
for col in calculatedStandardizedTrainingSet:
        if col in providedStandardizedTrainingSet.columns:
            print("\n######### "+col)
            print(calculatedStandardizedTrainingSet[col].describe())
            print(providedStandardizedTrainingSet[col].describe())
            plt.title(col)
            plt.hist(calculatedStandardizedTrainingSet[col]-providedStandardizedTrainingSet[col])
            plt.show()
            plt.plot(calculatedStandardizedTrainingSet[col],providedStandardizedTrainingSet[col], '.')
            plt.show()
# Out:
# ######### original_firstorder_Energy
# count    2.950000e+02
# mean    -4.412666e-17
# std      1.000000e+00
# min     -5.464456e-01
# 25%     -4.398466e-01
# 50%     -3.324665e-01
# 75%      5.570762e-02
# max      8.894396e+00
# Name: original_firstorder_Energy, dtype: float64
# count    3.000000e+02
# mean    -1.371877e-17
# std      1.000000e+00
# min     -5.303272e-01
# 25%     -4.283247e-01
# 50%     -3.204046e-01
# 75%      5.273909e-02
# max      9.478626e+00
# Name: original_firstorder_Energy, dtype: float64
# ######### original_firstorder_Entropy
# count    2.950000e+02
# mean    -4.936541e-15
# std      1.000000e+00
# min     -2.392098e+00
# 25%     -7.739889e-01
# 50%      1.759451e-01
# 75%      8.721187e-01
# max      1.519493e+00
# Name: original_firstorder_Entropy, dtype: float64
# count    3.000000e+02
# mean    -9.868813e-16
# std      1.000000e+00
# min     -2.293387e+00
# 25%     -7.731903e-01
# 50%      1.567997e-01
# 75%      8.770856e-01
# max      1.511395e+00
# Name: original_firstorder_Entropy, dtype: float64
# ######### original_firstorder_Kurtosis
# count    2.950000e+02
# mean    -6.749780e-16
# std      1.000000e+00
# min     -5.065451e-01
# 25%     -4.515467e-01
# 50%     -3.579919e-01
# 75%      3.093057e-02
# max      8.800760e+00
# Name: original_firstorder_Kurtosis, dtype: float64
# count    3.000000e+02
# mean     2.860675e-16
# std      1.000000e+00
# min     -5.550808e-01
# 25%     -4.985181e-01
# 50%     -3.866041e-01
# 75%      3.862764e-02
# max      6.626289e+00
# Name: original_firstorder_Kurtosis, dtype: float64
# ######### original_firstorder_Maximum
# count    2.950000e+02
# mean     1.204310e-17
# std      1.000000e+00
# min     -1.188638e+00
# 25%     -6.406210e-01
# 50%     -3.409044e-01
# 75%      2.698150e-01
# max      6.684250e+00
# Name: original_firstorder_Maximum, dtype: float64
# count    3.000000e+02
# mean     3.737751e-17
# std      1.000000e+00
# min     -1.182004e+00
# 25%     -6.454890e-01
# 50%     -3.333578e-01
# 75%      2.727283e-01
# max      6.687714e+00
# Name: original_firstorder_Maximum, dtype: float64
# ######### original_firstorder_MeanAbsoluteDeviation
# count    2.950000e+02
# mean     5.513774e-16
# std      1.000000e+00
# min     -1.704274e+00
# 25%     -7.855736e-01
# 50%     -2.243568e-02
# 75%      7.128345e-01
# max      2.463787e+00
# Name: original_firstorder_MeanAbsoluteDeviation, dtype: float64
# count    3.000000e+02
# mean     1.412458e-15
# std      1.000000e+00
# min     -1.672831e+00
# 25%     -7.976387e-01
# 50%     -4.612816e-02
# 75%      7.121241e-01
# max      2.441660e+00
# Name: original_firstorder_MeanAbsoluteDeviation, dtype: float64
# ######### original_firstorder_Mean
# count    2.950000e+02
# mean    -4.198148e-16
# std      1.000000e+00
# min     -3.121493e+00
# 25%     -6.842955e-01
# 50%      2.294754e-01
# 75%      8.018225e-01
# max      1.501519e+00
# Name: original_firstorder_Mean, dtype: float64
# count    3.000000e+02
# mean    -3.932040e-16
# std      1.000000e+00
# min     -3.122089e+00
# 25%     -6.932187e-01
# 50%      2.431064e-01
# 75%      7.976773e-01
# max      1.450211e+00
# Name: original_firstorder_Mean, dtype: float64
# ######### original_firstorder_Median
# count    2.950000e+02
# mean     5.268855e-17
# std      1.000000e+00
# min     -3.435067e+00
# 25%     -4.726092e-01
# 50%      5.027710e-01
# 75%      6.947341e-01
# max      9.904611e-01
# Name: original_firstorder_Median, dtype: float64
# count    3.000000e+02
# mean     5.070018e-17
# std      1.000000e+00
# min     -3.447685e+00
# 25%     -4.777268e-01
# 50%      5.113916e-01
# 75%      6.962005e-01
# max      9.825243e-01
# Name: original_firstorder_Median, dtype: float64
# ######### original_firstorder_Minimum
# count    2.950000e+02
# mean    -3.026769e-16
# std      1.000000e+00
# min     -2.269890e+00
# 25%     -8.638490e-01
# 50%     -2.558312e-01
# 75%      6.989467e-01
# max      4.579810e+00
# Name: original_firstorder_Minimum, dtype: float64
# count    3.000000e+02
# mean     1.965095e-16
# std      1.000000e+00
# min     -2.318274e+00
# 25%     -8.722230e-01
# 50%     -2.957566e-01
# 75%      6.446653e-01
# max      4.208498e+00
# Name: original_firstorder_Minimum, dtype: float64
# ######### original_firstorder_Range
# count    2.950000e+02
# mean    -3.217765e-17
# std      1.000000e+00
# min     -1.815498e+00
# 25%     -6.918296e-01
# 50%     -2.042876e-01
# 75%      4.155873e-01
# max      6.300916e+00
# Name: original_firstorder_Range, dtype: float64
# count    3.000000e+02
# mean    -1.265654e-16
# std      1.000000e+00
# min     -1.541164e+00
# 25%     -6.823226e-01
# 50%     -2.179123e-01
# 75%      4.066993e-01
# max      6.322003e+00
# Name: original_firstorder_Range, dtype: float64
# ######### original_firstorder_RootMeanSquared
# count    2.950000e+02
# mean    -4.045728e-16
# std      1.000000e+00
# min     -1.471478e+00
# 25%     -8.403347e-01
# 50%     -2.089976e-01
# 75%      7.435598e-01
# max      2.885277e+00
# Name: original_firstorder_RootMeanSquared, dtype: float64
# count    3.000000e+02
# mean     5.245804e-16
# std      1.000000e+00
# min     -1.488377e+00
# 25%     -8.383310e-01
# 50%     -1.873429e-01
# 75%      7.598812e-01
# max      2.872164e+00
# Name: original_firstorder_RootMeanSquared, dtype: float64
# ######### original_firstorder_Skewness
# count    2.950000e+02
# mean     2.423673e-16
# std      1.000000e+00
# min     -4.350111e+00
# 25%     -5.529271e-01
# 50%      2.111154e-01
# 75%      6.278210e-01
# max      3.846815e+00
# Name: original_firstorder_Skewness, dtype: float64
# count    3.000000e+02
# mean     8.761394e-16
# std      1.000000e+00
# min     -4.331653e+00
# 25%     -5.399537e-01
# 50%      2.211372e-01
# 75%      6.454713e-01
# max      2.224505e+00
# Name: original_firstorder_Skewness, dtype: float64
# ######### original_firstorder_Uniformity
# count    2.950000e+02
# mean    -5.627325e-16
# std      1.000000e+00
# min     -1.031242e+00
# 25%     -8.431265e-01
# 50%     -3.379867e-01
# 75%      6.156196e-01
# max      3.722796e+00
# Name: original_firstorder_Uniformity, dtype: float64
# count    3.000000e+02
# mean    -5.378105e-16
# std      1.000000e+00
# min     -1.033048e+00
# 25%     -8.535062e-01
# 50%     -3.297347e-01
# 75%      6.277900e-01
# max      3.770285e+00
# Name: original_firstorder_Uniformity, dtype: float64
# ######### original_firstorder_Variance
# count    2.950000e+02
# mean     1.921250e-16
# std      1.000000e+00
# min     -1.352932e+00
# 25%     -8.165512e-01
# 50%     -1.870808e-01
# 75%      6.076720e-01
# max      3.433601e+00
# Name: original_firstorder_Variance, dtype: float64
# count    3.000000e+02
# mean     6.911138e-17
# std      1.000000e+00
# min     -1.341086e+00
# 25%     -8.128373e-01
# 50%     -1.519147e-01
# 75%      5.907639e-01
# max      3.402322e+00
# Name: original_firstorder_Variance, dtype: float64
# ######### original_shape_Maximum3DDiameter
# count    2.950000e+02
# mean     1.007669e-15
# std      1.000000e+00
# min     -1.518218e+00
# 25%     -8.909969e-01
# 50%     -1.470436e-01
# 75%      6.502210e-01
# max      2.668007e+00
# Name: original_shape_Maximum3DDiameter, dtype: float64
# count    3.000000e+02
# mean    -1.577442e-17
# std      1.000000e+00
# min     -1.415051e+00
# 25%     -8.392143e-01
# 50%     -1.663815e-01
# 75%      5.402835e-01
# max      4.305292e+00
# Name: original_shape_Maximum3DDiameter, dtype: float64
# ######### original_shape_Sphericity
# count    2.950000e+02
# mean     1.274687e-15
# std      1.000000e+00
# min     -3.182249e+00
# 25%     -6.188735e-01
# 50%      5.135235e-02
# 75%      7.404994e-01
# max      2.464014e+00
# Name: original_shape_Sphericity, dtype: float64
# count    3.000000e+02
# mean    -2.912855e-15
# std      1.000000e+00
# min     -3.024637e+00
# 25%     -6.144260e-01
# 50%      4.015448e-02
# 75%      7.344540e-01
# max      2.447442e+00
# Name: original_shape_Sphericity, dtype: float64
# ######### original_shape_SurfaceArea
# count    2.950000e+02
# mean     2.500589e-16
# std      1.000000e+00
# min     -9.431219e-01
# 25%     -7.689337e-01
# 50%     -4.197563e-01
# 75%      4.053848e-01
# max      4.569028e+00
# Name: original_shape_SurfaceArea, dtype: float64
# count    3.000000e+02
# mean     1.272131e-17
# std      1.000000e+00
# min     -8.946216e-01
# 25%     -7.333378e-01
# 50%     -4.173696e-01
# 75%      3.462198e-01
# max      5.220107e+00
# Name: original_shape_SurfaceArea, dtype: float64
# ######### original_shape_SurfaceVolumeRatio
# count    2.950000e+02
# mean     2.193349e-15
# std      1.000000e+00
# min     -1.432055e+00
# 25%     -7.959825e-01
# 50%     -2.361920e-01
# 75%      5.463810e-01
# max      3.006435e+00
# Name: original_shape_SurfaceVolumeRatio, dtype: float64
# count    3.000000e+02
# mean     7.227552e-16
# std      1.000000e+00
# min     -1.446676e+00
# 25%     -7.936163e-01
# 50%     -2.186236e-01
# 75%      5.655428e-01
# max      2.993048e+00
# Name: original_shape_SurfaceVolumeRatio, dtype: float64
# ######### original_shape_VoxelVolume
# count    2.950000e+02
# mean     9.996712e-18
# std      1.000000e+00
# min     -6.905269e-01
# 25%     -6.277503e-01
# 50%     -4.421229e-01
# 75%      1.710346e-01
# max      5.010885e+00
# Name: original_shape_VoxelVolume, dtype: float64
# count    3.000000e+02
# mean    -1.547373e-17
# std      1.000000e+00
# min     -6.713677e-01
# 25%     -6.113130e-01
# 50%     -4.421235e-01
# 75%      1.504328e-01
# max      5.423278e+00
# Name: original_shape_VoxelVolume, dtype: float64
# ######### original_glcm_Autocorrelation
# count    2.950000e+02
# mean    -2.675826e-15
# std      1.000000e+00
# min     -2.255235e+00
# 25%     -7.727469e-01
# 50%      4.735230e-04
# 75%      7.744959e-01
# max      2.214413e+00
# Name: original_glcm_Autocorrelation, dtype: float64
# count    3.000000e+02
# mean    -1.213844e-16
# std      1.000000e+00
# min     -2.285141e+00
# 25%     -7.065593e-01
# 50%      3.360648e-02
# 75%      7.537628e-01
# max      2.232661e+00
# Name: original_glcm_Autocorrelation, dtype: float64
# ######### original_glcm_ClusterProminence
# count    2.950000e+02
# mean     6.797764e-16
# std      1.000000e+00
# min     -9.615561e-01
# 25%     -6.669162e-01
# 50%     -2.925859e-01
# 75%      3.337397e-01
# max      7.236781e+00
# Name: original_glcm_ClusterProminence, dtype: float64
# count    3.000000e+02
# mean    -1.752302e-16
# std      1.000000e+00
# min     -9.565067e-01
# 25%     -6.779686e-01
# 50%     -2.790478e-01
# 75%      3.343207e-01
# max      8.015678e+00
# Name: original_glcm_ClusterProminence, dtype: float64
# ######### original_glcm_ClusterShade
# count    2.950000e+02
# mean    -2.483889e-16
# std      1.000000e+00
# min     -5.111636e+00
# 25%     -3.824635e-01
# 50%      1.102069e-01
# 75%      4.905851e-01
# max      6.877433e+00
# Name: original_glcm_ClusterShade, dtype: float64
# count    3.000000e+02
# mean     2.379578e-16
# std      1.000000e+00
# min     -4.983429e+00
# 25%     -4.172689e-01
# 50%      1.391931e-01
# 75%      4.977043e-01
# max      7.493269e+00
# Name: original_glcm_ClusterShade, dtype: float64
# ######### original_glcm_ClusterTendency
# count    2.950000e+02
# mean    -4.299762e-17
# std      1.000000e+00
# min     -1.290246e+00
# 25%     -7.944422e-01
# 50%     -1.917221e-01
# 75%      6.263168e-01
# max      3.884327e+00
# Name: original_glcm_ClusterTendency, dtype: float64
# count    3.000000e+02
# mean    -6.237603e-16
# std      1.000000e+00
# min     -1.285369e+00
# 25%     -7.928714e-01
# 50%     -1.591919e-01
# 75%      6.077802e-01
# max      3.849012e+00
# Name: original_glcm_ClusterTendency, dtype: float64
# ######### original_glcm_Contrast
# count    2.950000e+02
# mean    -3.466154e-16
# std      1.000000e+00
# min     -9.231874e-01
# 25%     -6.830643e-01
# 50%     -4.128497e-01
# 75%      2.688166e-01
# max      3.920316e+00
# Name: original_glcm_Contrast, dtype: float64
# count    3.000000e+02
# mean     9.692247e-16
# std      1.000000e+00
# min     -9.199448e-01
# 25%     -6.912479e-01
# 50%     -4.065565e-01
# 75%      2.578233e-01
# max      3.923271e+00
# Name: original_glcm_Contrast, dtype: float64
# ######### original_glcm_Correlation
# count    2.950000e+02
# mean     2.491416e-16
# std      1.000000e+00
# min     -4.147222e+00
# 25%     -5.208477e-01
# 50%      2.097611e-01
# 75%      7.316662e-01
# max      1.593619e+00
# Name: original_glcm_Correlation, dtype: float64
# count    3.000000e+02
# mean     6.853777e-15
# std      1.000000e+00
# min     -4.153893e+00
# 25%     -5.084799e-01
# 50%      2.327030e-01
# 75%      7.304996e-01
# max      1.591246e+00
# Name: original_glcm_Correlation, dtype: float64
# ######### original_glcm_DifferenceAverage
# count    2.950000e+02
# mean    -7.703819e-16
# std      1.000000e+00
# min     -1.367741e+00
# 25%     -7.973018e-01
# 50%     -2.733518e-01
# 75%      6.181227e-01
# max      2.923207e+00
# Name: original_glcm_DifferenceAverage, dtype: float64
# count    3.000000e+02
# mean    -2.427688e-16
# std      1.000000e+00
# min     -1.351389e+00
# 25%     -7.909620e-01
# 50%     -2.664944e-01
# 75%      6.244351e-01
# max      2.920629e+00
# Name: original_glcm_DifferenceAverage, dtype: float64
# ######### original_glcm_DifferenceEntropy
# count    2.950000e+02
# mean    -5.511599e-16
# std      1.000000e+00
# min     -2.239257e+00
# 25%     -7.855335e-01
# 50%     -1.940366e-04
# 75%      7.928719e-01
# max      2.021797e+00
# Name: original_glcm_DifferenceEntropy, dtype: float64
# count    3.000000e+02
# mean    -1.416460e-16
# std      1.000000e+00
# min     -2.165330e+00
# 25%     -7.709079e-01
# 50%      2.183736e-02
# 75%      8.119826e-01
# max      2.013436e+00
# Name: original_glcm_DifferenceEntropy, dtype: float64
# ######### original_glcm_Id
# count    2.950000e+02
# mean     9.215792e-17
# std      1.000000e+00
# min     -1.656009e+00
# 25%     -9.331568e-01
# 50%      2.095154e-02
# 75%      8.608366e-01
# max      2.086468e+00
# Name: original_glcm_Id, dtype: float64
# count    3.000000e+02
# mean    -1.408827e-16
# std      1.000000e+00
# min     -1.651589e+00
# 25%     -9.351841e-01
# 50%     -9.157180e-03
# 75%      8.742354e-01
# max      2.028410e+00
# Name: original_glcm_Id, dtype: float64
# ######### original_glcm_Idm
# count    2.950000e+02
# mean    -1.328739e-16
# std      1.000000e+00
# min     -1.609091e+00
# 25%     -9.229728e-01
# 50%      7.081831e-03
# 75%      8.712352e-01
# max      2.100640e+00
# Name: original_glcm_Idm, dtype: float64
# count    3.000000e+02
# mean    -6.141702e-16
# std      1.000000e+00
# min     -1.604503e+00
# 25%     -9.247483e-01
# 50%     -1.170325e-02
# 75%      8.710349e-01
# max      2.042647e+00
# Name: original_glcm_Idm, dtype: float64
# ######### original_glcm_Idmn
# count    2.950000e+02
# mean    -3.217878e-14
# std      1.000000e+00
# min     -4.004565e+00
# 25%     -5.829172e-01
# 50%      3.707712e-01
# 75%      8.151413e-01
# max      1.034909e+00
# Name: original_glcm_Idmn, dtype: float64
# count    3.000000e+02
# mean     2.243539e-14
# std      1.000000e+00
# min     -4.030204e+00
# 25%     -5.886501e-01
# 50%      3.599082e-01
# 75%      8.111395e-01
# max      1.039176e+00
# Name: original_glcm_Idmn, dtype: float64
# ######### original_glcm_Idn
# count    2.950000e+02
# mean    -9.489208e-15
# std      1.000000e+00
# min     -2.834039e+00
# 25%     -8.247008e-01
# 50%      2.231564e-01
# 75%      8.974690e-01
# max      1.526138e+00
# Name: original_glcm_Idn, dtype: float64
# count    3.000000e+02
# mean    -3.629319e-15
# std      1.000000e+00
# min     -2.842104e+00
# 25%     -8.222093e-01
# 50%      1.849729e-01
# 75%      9.056434e-01
# max      1.518105e+00
# Name: original_glcm_Idn, dtype: float64
# ######### original_glcm_Imc1
# count    2.950000e+02
# mean    -7.310536e-16
# std      1.000000e+00
# min     -3.477966e+00
# 25%     -6.546192e-01
# 50%     -6.535320e-02
# 75%      7.258808e-01
# max      2.834579e+00
# Name: original_glcm_Imc1, dtype: float64
# count    3.000000e+02
# mean    -1.676159e-15
# std      1.000000e+00
# min     -3.415890e+00
# 25%     -6.493684e-01
# 50%     -8.504791e-02
# 75%      7.381900e-01
# max      2.807260e+00
# Name: original_glcm_Imc1, dtype: float64
# ######### original_glcm_Imc2
# count    2.950000e+02
# mean    -8.198715e-16
# std      1.000000e+00
# min     -6.016164e+00
# 25%     -3.805488e-01
# 50%      1.951483e-01
# 75%      6.348353e-01
# max      1.677409e+00
# Name: original_glcm_Imc2, dtype: float64
# count    3.000000e+02
# mean    -5.351275e-16
# std      1.000000e+00
# min     -5.947872e+00
# 25%     -3.870863e-01
# 50%      2.134491e-01
# 75%      6.663058e-01
# max      1.654585e+00
# Name: original_glcm_Imc2, dtype: float64
# ######### original_glcm_InverseVariance
# count    2.950000e+02
# mean     3.302443e-15
# std      1.000000e+00
# min     -2.000929e+00
# 25%     -8.292455e-01
# 50%      6.285387e-02
# 75%      8.161687e-01
# max      1.987169e+00
# Name: original_glcm_InverseVariance, dtype: float64
# count    3.000000e+02
# mean    -4.070818e-17
# std      1.000000e+00
# min     -1.996028e+00
# 25%     -8.307151e-01
# 50%      7.878824e-02
# 75%      8.113607e-01
# max      1.960243e+00
# Name: original_glcm_InverseVariance, dtype: float64
# ######### original_glcm_JointEnergy
# count    2.950000e+02
# mean     1.567484e-16
# std      1.000000e+00
# min     -8.478869e-01
# 25%     -7.654678e-01
# 50%     -3.577621e-01
# 75%      4.759141e-01
# max      6.271254e+00
# Name: original_glcm_JointEnergy, dtype: float64
# count    3.000000e+02
# mean    -6.777912e-16
# std      1.000000e+00
# min     -8.496721e-01
# 25%     -7.676520e-01
# 50%     -3.595146e-01
# 75%      4.940339e-01
# max      6.367455e+00
# Name: original_glcm_JointEnergy, dtype: float64
# ######### original_glcm_JointEntropy
# count    2.950000e+02
# mean    -5.584045e-16
# std      1.000000e+00
# min     -2.178621e+00
# 25%     -7.876180e-01
# 50%      7.952519e-02
# 75%      8.051089e-01
# max      1.722235e+00
# Name: original_glcm_JointEntropy, dtype: float64
# count    3.000000e+02
# mean     3.354030e-16
# std      1.000000e+00
# min     -2.104082e+00
# 25%     -7.787868e-01
# 50%      6.384105e-02
# 75%      8.147628e-01
# max      1.713177e+00
# Name: original_glcm_JointEntropy, dtype: float64
# ######### original_glcm_MaximumProbability
# count    2.950000e+02
# mean    -7.615377e-16
# std      1.000000e+00
# min     -1.116450e+00
# 25%     -8.712887e-01
# 50%     -2.412547e-01
# 75%      6.828114e-01
# max      5.005107e+00
# Name: original_glcm_MaximumProbability, dtype: float64
# count    3.000000e+02
# mean    -5.014507e-17
# std      1.000000e+00
# min     -1.117125e+00
# 25%     -8.688225e-01
# 50%     -2.226365e-01
# 75%      6.913076e-01
# max      5.057209e+00
# Name: original_glcm_MaximumProbability, dtype: float64
# ######### original_glcm_SumAverage
# count    2.950000e+02
# mean    -5.411867e-16
# std      1.000000e+00
# min     -2.654140e+00
# 25%     -6.075643e-01
# 50%      3.438398e-02
# 75%      7.515629e-01
# max      1.918303e+00
# Name: original_glcm_SumAverage, dtype: float64
# count    3.000000e+02
# mean     1.001051e-15
# std      1.000000e+00
# min     -2.753054e+00
# 25%     -6.106537e-01
# 50%      4.117880e-02
# 75%      7.204410e-01
# max      1.934817e+00
# Name: original_glcm_SumAverage, dtype: float64
# ######### original_glcm_SumEntropy
# count    2.950000e+02
# mean     4.066545e-15
# std      1.000000e+00
# min     -2.356488e+00
# 25%     -7.797636e-01
# 50%      1.255943e-01
# 75%      8.940550e-01
# max      1.619940e+00
# Name: original_glcm_SumEntropy, dtype: float64
# count    3.000000e+02
# mean    -8.557738e-16
# std      1.000000e+00
# min     -2.368579e+00
# 25%     -7.747823e-01
# 50%      1.201975e-01
# 75%      9.254649e-01
# max      1.610936e+00
# Name: original_glcm_SumEntropy, dtype: float64
# ######### original_glrlm_GrayLevelNonUniformity
# count    2.950000e+02
# mean     1.335090e-16
# std      1.000000e+00
# min     -5.542137e-01
# 25%     -5.314914e-01
# 50%     -4.306649e-01
# 75%      3.042233e-02
# max      7.539012e+00
# Name: original_glrlm_GrayLevelNonUniformity, dtype: float64
# count    3.000000e+02
# mean     1.072290e-16
# std      1.000000e+00
# min     -5.450285e-01
# 25%     -5.233980e-01
# 50%     -4.265947e-01
# 75%      1.484246e-02
# max      7.845670e+00
# Name: original_glrlm_GrayLevelNonUniformity, dtype: float64
# ######### original_glrlm_HighGrayLevelRunEmphasis
# count    2.950000e+02
# mean     7.538226e-16
# std      1.000000e+00
# min     -2.129894e+00
# 25%     -7.256907e-01
# 50%     -3.218815e-02
# 75%      7.725299e-01
# max      2.443244e+00
# Name: original_glrlm_HighGrayLevelRunEmphasis, dtype: float64
# count    3.000000e+02
# mean     3.619327e-16
# std      1.000000e+00
# min     -2.161998e+00
# 25%     -7.147344e-01
# 50%     -1.388965e-02
# 75%      7.355300e-01
# max      2.469136e+00
# Name: original_glrlm_HighGrayLevelRunEmphasis, dtype: float64
# ######### original_glrlm_LongRunEmphasis
# count    2.950000e+02
# mean    -2.030391e-16
# std      1.000000e+00
# min     -8.182352e-01
# 25%     -7.098393e-01
# 50%     -3.554470e-01
# 75%      3.861236e-01
# max      7.149059e+00
# Name: original_glrlm_LongRunEmphasis, dtype: float64
# count    3.000000e+02
# mean    -2.057613e-16
# std      1.000000e+00
# min     -8.204050e-01
# 25%     -7.103320e-01
# 50%     -3.575760e-01
# 75%      4.087710e-01
# max      7.276957e+00
# Name: original_glrlm_LongRunEmphasis, dtype: float64
# ######### original_glrlm_LongRunHighGrayLevelEmphasis
# count    2.950000e+02
# mean     6.256765e-16
# std      1.000000e+00
# min     -9.653819e-01
# 25%     -6.844688e-01
# 50%     -3.702813e-01
# 75%      3.829318e-01
# max      5.613855e+00
# Name: original_glrlm_LongRunHighGrayLevelEmphasis, dtype: float64
# count    3.000000e+02
# mean     9.671893e-16
# std      1.000000e+00
# min     -9.757692e-01
# 25%     -6.879876e-01
# 50%     -3.736158e-01
# 75%      4.371958e-01
# max      5.808224e+00
# Name: original_glrlm_LongRunHighGrayLevelEmphasis, dtype: float64
# ######### original_glrlm_LongRunLowGrayLevelEmphasis
# count    2.950000e+02
# mean    -1.392483e-16
# std      1.000000e+00
# min     -3.465121e-01
# 25%     -2.681653e-01
# 50%     -2.238733e-01
# 75%     -8.997485e-02
# max      1.017039e+01
# Name: original_glrlm_LongRunLowGrayLevelEmphasis, dtype: float64
# count    3.000000e+02
# mean    -2.264855e-16
# std      1.000000e+00
# min     -3.274447e-01
# 25%     -2.558591e-01
# 50%     -2.059701e-01
# 75%     -9.459868e-02
# max      1.088840e+01
# Name: original_glrlm_LongRunLowGrayLevelEmphasis, dtype: float64
# ######### original_glrlm_LowGrayLevelRunEmphasis
# count    2.950000e+02
# mean    -3.400293e-16
# std      1.000000e+00
# min     -5.625898e-01
# 25%     -4.451282e-01
# 50%     -3.040820e-01
# 75%      6.220606e-02
# max      1.065285e+01
# Name: original_glrlm_LowGrayLevelRunEmphasis, dtype: float64
# count    3.000000e+02
# mean    -3.128979e-16
# std      1.000000e+00
# min     -5.313375e-01
# 25%     -4.198864e-01
# 50%     -2.759430e-01
# 75%      1.427014e-02
# max      1.110240e+01
# Name: original_glrlm_LowGrayLevelRunEmphasis, dtype: float64
# ######### original_glrlm_RunLengthNonUniformity
# count    2.950000e+02
# mean     1.928777e-16
# std      1.000000e+00
# min     -7.070806e-01
# 25%     -6.030296e-01
# 50%     -3.526881e-01
# 75%      2.246731e-01
# max      7.566927e+00
# Name: original_glrlm_RunLengthNonUniformity, dtype: float64
# count    3.000000e+02
# mean     3.016106e-17
# std      1.000000e+00
# min     -6.897750e-01
# 25%     -5.892364e-01
# 50%     -3.544250e-01
# 75%      2.150099e-01
# max      8.005513e+00
# Name: original_glrlm_RunLengthNonUniformity, dtype: float64
# ######### original_glrlm_RunPercentage
# count    2.950000e+02
# mean    -4.186670e-15
# std      1.000000e+00
# min     -2.534861e+00
# 25%     -8.173411e-01
# 50%      1.460062e-01
# 75%      9.511029e-01
# max      1.359134e+00
# Name: original_glrlm_RunPercentage, dtype: float64
# count    3.000000e+02
# mean     2.879733e-15
# std      1.000000e+00
# min     -2.499362e+00
# 25%     -8.316672e-01
# 50%      1.639987e-01
# 75%      9.509252e-01
# max      1.356922e+00
# Name: original_glrlm_RunPercentage, dtype: float64
# ######### original_glrlm_ShortRunEmphasis
# count    2.950000e+02
# mean    -6.320744e-16
# std      1.000000e+00
# min     -3.139265e+00
# 25%     -7.555575e-01
# 50%      1.928978e-01
# 75%      8.948164e-01
# max      1.311155e+00
# Name: original_glrlm_ShortRunEmphasis, dtype: float64
# count    3.000000e+02
# mean     2.103410e-15
# std      1.000000e+00
# min     -2.967977e+00
# 25%     -7.589291e-01
# 50%      1.998008e-01
# 75%      9.028560e-01
# max      1.309620e+00
# Name: original_glrlm_ShortRunEmphasis, dtype: float64
# ######### original_glrlm_ShortRunHighGrayLevelEmphasis
# count    2.950000e+02
# mean    -3.096581e-15
# std      1.000000e+00
# min     -2.339359e+00
# 25%     -7.402642e-01
# 50%      4.164994e-02
# 75%      6.934293e-01
# max      3.002234e+00
# Name: original_glrlm_ShortRunHighGrayLevelEmphasis, dtype: float64
# count    3.000000e+02
# mean     1.146860e-15
# std      1.000000e+00
# min     -2.315363e+00
# 25%     -7.171656e-01
# 50%      2.973441e-02
# 75%      6.784050e-01
# max      3.018871e+00
# Name: original_glrlm_ShortRunHighGrayLevelEmphasis, dtype: float64
# ######### original_glrlm_ShortRunLowGrayLevelEmphasis
# count    2.950000e+02
# mean    -6.887146e-17
# std      1.000000e+00
# min     -6.392985e-01
# 25%     -4.932651e-01
# 50%     -3.125622e-01
# 75%      7.872562e-02
# max      9.646250e+00
# Name: original_glrlm_ShortRunLowGrayLevelEmphasis, dtype: float64
# count    3.000000e+02
# mean    -5.965598e-16
# std      1.000000e+00
# min     -6.136560e-01
# 25%     -4.710663e-01
# 50%     -2.939120e-01
# 75%      3.660221e-02
# max      1.002654e+01
# Name: original_glrlm_ShortRunLowGrayLevelEmphasis, dtype: float64

# %% [markdown]
# ### Conclusions:
# - All features having the same names have a linear relationship, passing by the origin.
# - We will use the calculated one when possible and for the missing values (the empty mask), we will keep the provided data. We can do so only after data standardization, as when not standardize the provided and calculated features having the same have values in different scales

# %% [markdown]
# ## Preparing the data

# %%
providedStandardizedTrainingSet=prepareDataSet('Training')
providedStandardizedTestingSet=prepareDataSet('Testing')
calculatedStandardizedTrainingSet=calculateRadiomics('Training')
calculatedStandardizedTestingSet=calculateRadiomics('Testing')
# Out:
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %%
# Let's use calculcated data instead of provided ones when the exist, except for the missing ones where we keep the provided ones. 
# For a scale issue, we work on standardized data
def mergeDataset (providedSet, calculatedSet):
    providedDataSet=providedSet
    calculatedDataSet=calculatedSet
    for col in calculatedDataSet:
        if col in providedDataSet.columns :
            providedDataSet[col][calculatedDataSet[col].notnull()]=calculatedDataSet[col][calculatedDataSet[col].notnull()]
    return providedDataSet

# %%
# We export the prepared set, so they can be used in R
mergeDataset(providedStandardizedTrainingSet, calculatedStandardizedTrainingSet).to_csv('mergedStandardizedTrainingSet.csv', index=True)
mergeDataset(providedStandardizedTestingSet, calculatedStandardizedTestingSet).to_csv('mergedStandardizedTestingSet.csv', index=True)
# Out:
# C:\Users\ddalt\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
